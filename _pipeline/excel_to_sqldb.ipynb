# %%
# %cd /mnt/mol/Bioinfo_Routine/Variant_Vault/_pipeline
# Out:
# /mnt/mol/Bioinfo_Routine/Variant_Vault/_pipeline

# %%
import hashlib

def generate_unique_id(data):
    # Create a hash object
    hash_object = hashlib.sha256(data.encode())
    
    # Convert the hash to a hexadecimal string
    hex_dig = hash_object.hexdigest()
    
    # Convert hexadecimal to integer (you can also truncate this to fit your needs)
    unique_id = str(int(hex_dig, 16))
    
    return unique_id

# %%
import os
from PBTK import *
import pandas as pd
from sqlalchemy import create_engine, Column, String, MetaData, Table
import sqlite3

vava_db_dir = '/home/sysadmin/vava_db/'


current_directory = os.getcwd()
# Get the parent directory
parent_directory = os.path.dirname(current_directory)
input_temp_dir = os.path.join(os.getcwd(),'input_temp')
excel_path = os.path.join(current_directory, 'bahan_db','Rekap_TSHC_MAF_20240304.xlsx')
# Read the Excel file
excel_data = pd.read_excel(os.path.join(current_directory,excel_path))
bahan_db = os.listdir(os.path.join(current_directory, 'bahan_db_brca',))
bahan_db
# Out:
# ['Rekap_TSHC_MAF_20230414.xlsx',
#  'Rekap_TSHC_MAF_20220816.xlsx',
#  'Rekap_TSHC_MAF_20230116.xlsx',
#  'Rekap_TSHC_MAF_20230102.xlsx',
#  'Rekap_TSHC_MAF_20210804.xlsx',
#  'Rekap_TSHC_MAF_20230313.xlsx',
#  'Rekap_TSHC_MAF_20220224.xlsx',
#  'Rekap_TSHC_MAF_20230515.xlsx',
#  'Rekap_TSHC_MAF_20231120.xlsx',
#  'Rekap_TSHC_MAF_20230605.xlsx',
#  'Rekap_TSHC_MAF_20230306.xlsx',
#  'Rekap_TSHC_MAF_20220819.xlsx',
#  'Rekap_TSHC_MAF_20230717.xlsx',
#  'Rekap_TSHC_MAF_20230502.xlsx',
#  'Rekap_TSHC_MAF_20230424.xlsx',
#  'Rekap_TSHC_MAF_20240119.xlsx',
#  'Rekap_TSHC_MAF_20231016.xlsx',
#  'Rekap_TSHC_MAF_20240205.xlsx',
#  'Rekap_TSHC_MAF_20221121.xlsx',
#  'Rekap_TSHC_MAF_20240304.xlsx',
#  'Rekap_TSHC_MAF_20220919.xlsx',
#  'Rekap_TSHC_MAF_20220801.xlsx',
#  'Rekap_TSHC_MAF_20230807.xlsx',
#  'Rekap_TSHC_MAF_20230626.xlsx',
#  'Rekap_TSHC_MAF_20230703.xlsx',
#  'Rekap_TSHC_MAF_20220608.xlsx',
#  'Rekap_TSHC_MAF_20210610.xlsx',
#  'Rekap_TSHC_MAF_20230320.xlsx',
#  'Rekap_TSHC_MAF_20231218.xlsx',
#  'Rekap_TSHC_MAF_20220622.xlsx',
#  'Rekap_TSHC_MAF_20221019.xlsx',
#  'Rekap_TSHC_MAF_20221003.xlsx',
#  'Rekap_TSHC_MAF_20210624.xlsx',
#  'Rekap_TSHC_MAF_20210714.xlsx',
#  'Rekap_TSHC_MAF_20230712.xlsx',
#  'Rekap_TSHC_MAF_20230516.xlsx',
#  'Rekap_TSHC_MAF_20221219.xlsx',
#  'Rekap_TSHC_MAF_20230331.xlsx',
#  'Rekap_TSHC_MAF_20221205.xlsx',
#  'Rekap_TSHC_MAF_20230918.xlsx',
#  'Rekap_TSHC_MAF_20231204.xlsx',
#  'Rekap_TSHC_MAF_20231122.xlsx',
#  'Rekap_TSHC_MAF_20221107.xlsx',
#  'Rekap_TSHC_MAF_20240108.xlsx',
#  'Rekap_TSHC_MAF_20240219.xlsx',
#  'Rekap_TSHC_MAF_20220519.xlsx',
#  'Rekap_TSHC_MAF_20230823.xlsx',
#  'Rekap_TSHC_MAF_20210723.xlsx',
#  'Rekap_TSHC_MAF_20220720.xlsx',
#  'Rekap_TSHC_MAF_20231002.xlsx',
#  'Rekap_TSHC_MAF_20230706.xlsx',
#  'Rekap_TSHC_MAF_20231206.xlsx',
#  'Rekap_TSHC_MAF_20231106.xlsx',
#  'Rekap_TSHC_MAF_20230206.xlsx',
#  'Rekap_TSHC_MAF_20230220.xlsx',
#  'Rekap_TSHC_MAF_20230904.xlsx',
#  'Rekap_TSHC_MAF_20210707.xlsx',
#  'Rekap_TSHC_MAF_20220421.xlsx',
#  'Rekap_TSHC_MAF_20220808.xlsx',
#  'Rekap_TSHC_MAF_20240117.xlsx']

# %%
len(bahan_db)
# Out:
# 60

# %%
bahan_db_df = pd.DataFrame()
bahan_db_df

# Loop through the files, read each into a DataFrame, and append it to the merged_df
for file in bahan_db:
    print(file)
    file_path = os.path.join(current_directory, 'bahan_db', file)
    df_temp = pd.read_excel(file_path, engine='openpyxl')
    bahan_db_df = pd.concat([bahan_db_df, df_temp], ignore_index=True)
# Out:
# Rekap_TSHC_MAF_20230414.xlsx
# Rekap_TSHC_MAF_20220816.xlsx
# Rekap_TSHC_MAF_20230116.xlsx
# Rekap_TSHC_MAF_20230102.xlsx
# Rekap_TSHC_MAF_20210804.xlsx
# Rekap_TSHC_MAF_20230313.xlsx
# Rekap_TSHC_MAF_20220224.xlsx
# Rekap_TSHC_MAF_20230515.xlsx
# Rekap_TSHC_MAF_20231120.xlsx
# Rekap_TSHC_MAF_20230605.xlsx
# Rekap_TSHC_MAF_20230306.xlsx
# Rekap_TSHC_MAF_20220819.xlsx
# Rekap_TSHC_MAF_20230717.xlsx
# Rekap_TSHC_MAF_20230502.xlsx
# Rekap_TSHC_MAF_20230424.xlsx
# Rekap_TSHC_MAF_20240119.xlsx
# Rekap_TSHC_MAF_20231016.xlsx
# Rekap_TSHC_MAF_20240205.xlsx
# Rekap_TSHC_MAF_20221121.xlsx
# Rekap_TSHC_MAF_20240304.xlsx
# Rekap_TSHC_MAF_20220919.xlsx
# Rekap_TSHC_MAF_20220801.xlsx
# Rekap_TSHC_MAF_20230807.xlsx
# Rekap_TSHC_MAF_20230626.xlsx
# Rekap_TSHC_MAF_20230703.xlsx
# Rekap_TSHC_MAF_20220608.xlsx
# Rekap_TSHC_MAF_20210610.xlsx
# Rekap_TSHC_MAF_20230320.xlsx
# Rekap_TSHC_MAF_20231218.xlsx
# Rekap_TSHC_MAF_20220622.xlsx
# Rekap_TSHC_MAF_20221019.xlsx
# Rekap_TSHC_MAF_20221003.xlsx
# Rekap_TSHC_MAF_20210624.xlsx
# Rekap_TSHC_MAF_20210714.xlsx
# Rekap_TSHC_MAF_20230712.xlsx
# Rekap_TSHC_MAF_20230516.xlsx
# Rekap_TSHC_MAF_20221219.xlsx
# Rekap_TSHC_MAF_20230331.xlsx
# Rekap_TSHC_MAF_20221205.xlsx
# Rekap_TSHC_MAF_20230918.xlsx
# Rekap_TSHC_MAF_20231204.xlsx
# Rekap_TSHC_MAF_20231122.xlsx
# Rekap_TSHC_MAF_20221107.xlsx
# Rekap_TSHC_MAF_20240108.xlsx
# Rekap_TSHC_MAF_20240219.xlsx
# Rekap_TSHC_MAF_20220519.xlsx
# Rekap_TSHC_MAF_20230823.xlsx
# Rekap_TSHC_MAF_20210723.xlsx
# Rekap_TSHC_MAF_20220720.xlsx
# Rekap_TSHC_MAF_20231002.xlsx
# Rekap_TSHC_MAF_20230706.xlsx
# Rekap_TSHC_MAF_20231206.xlsx
# Rekap_TSHC_MAF_20231106.xlsx
# Rekap_TSHC_MAF_20230206.xlsx
# Rekap_TSHC_MAF_20230220.xlsx
# Rekap_TSHC_MAF_20230904.xlsx
# Rekap_TSHC_MAF_20210707.xlsx
# Rekap_TSHC_MAF_20220421.xlsx
# Rekap_TSHC_MAF_20220808.xlsx
# Rekap_TSHC_MAF_20240117.xlsx

# %%
bahan_db_df
# Out:
#         Unnamed: 0     Rundate     SampleID   Gene  \
# 0                0  14/04/2023  R2303061875   SDHB
# 1                7  14/04/2023  R2303061875   SDHB
# 2               12  14/04/2023  R2303061875   SDHB
# 3               16  14/04/2023  R2303061875   SDHB
# 4               23  14/04/2023  R2303061875  MUTYH
# ...            ...         ...          ...    ...
# 162647        1780  17/01/2024  R2401062088  CHEK2
# 162648        1783  17/01/2024  R2401062088  CHEK2
# 162649        1784  17/01/2024  R2401062088  CHEK2
# 162650        1787  17/01/2024  R2401062088  CHEK2
# 162651        1788  17/01/2024  R2401062088  CHEK2
#
#                                     Nucleotide [AAchange]    dbSNP ID  \
# 0             g.chr1:17032891T>C|NM_003000|c.e3-169A>G|--         NaN
# 1             g.chr1:17044657T>C|NM_003000|c.e2-104A>G|--         NaN
# 2             g.chr1:17044999C>T|NM_003000|c.e2+111G>A|--         NaN
# 3              g.chr1:17054002G>T|NM_003000|c.18C>A|p.A6A   rs2746462
# 4         g.chr1:45330597G>C|NM_001048171|c.e3+1160C>G|--   rs3219493
# ...                                                   ...         ...
# 162647   g.chr22:28694987C>G|NM_001005735|c.e13-140G>C|--  rs17886236
# 162648    g.chr22:28695049G>C|NM_001005735|c.e13-78C>G|--         NaN
# 162649    g.chr22:28703766T>C|NM_001005735|c.e9+200A>G|--         NaN
# 162650     g.chr22:28734312C>T|NM_001005735|c.e3-91G>A|--         NaN
# 162651  g.chr22:28734825_28734826insA|NM_001005735|c.e...         NaN
#
#        Chromosome     Start       End Ref Alt Variant Type  \
# 0            chr1  17032891  17032891   T   C          SNP
# 1            chr1  17044657  17044657   T   C          SNP
# 2            chr1  17044999  17044999   C   T          SNP
# 3            chr1  17054002  17054002   G   T          SNP
# 4            chr1  45330597  45330597   G   C          SNP
# ...           ...       ...       ...  ..  ..          ...
# 162647      chr22  28694987  28694987   C   G          SNP
# 162648      chr22  28695049  28695049   G   C          SNP
# 162649      chr22  28703766  28703766   T   C          SNP
# 162650      chr22  28734312  28734312   C   T          SNP
# 162651      chr22  28734825  28734826   -   A          INS
#
#        Variant_Classification     VAF Genotype  alt_count  ref_count   DP  \
# 0                      Intron   49.74      Het         96         97  193
# 1                      Intron   45.91      Het         73         86  159
# 2                      Intron   44.70      Het         97        120  217
# 3                      Silent   99.66   HomAlt        876          3  879
# 4                      Intron  100.00   HomAlt        545          0  545
# ...                       ...     ...      ...        ...        ...  ...
# 162647                 Intron   68.18      Het         30         14   44
# 162648                 Intron   58.62      Het         51         36   87
# 162649                 Intron   46.67      Het          7          8   15
# 162650                 Intron   31.71      Het         13         28   41
# 162651                 Intron   50.00      Het         13         13   26
#
#        Clinical Relevance   P/LP_Result Mode_of_Inheritance  \
# 0                     NaN  not detected                  AD
# 1                     NaN  not detected                  AD
# 2                     NaN  not detected                  AD
# 3                  Benign  not detected                  AD
# 4                  Benign  not detected                  AR
# ...                   ...           ...                 ...
# 162647      Likely_benign  not detected                 NaN
# 162648                NaN  not detected                 NaN
# 162649                NaN  not detected                 NaN
# 162650                NaN  not detected                 NaN
# 162651                NaN  not detected                 NaN
#
#                          Disease_Name
# 0       Paragangliomas 4 (MIM 115310)
# 1       Paragangliomas 4 (MIM 115310)
# 2       Paragangliomas 4 (MIM 115310)
# 3       Paragangliomas 4 (MIM 115310)
# 4          Pilomatrixoma (MIM 132600)
# ...                               ...
# 162647                            NaN
# 162648                            NaN
# 162649                            NaN
# 162650                            NaN
# 162651                            NaN
#
# [162652 rows x 22 columns]

# %%
bahan_db_df = bahan_db_df.drop(columns='Unnamed: 0')
bahan_db_df.fillna(' ', inplace=True)
bahan_db_df
# Out:
#            Rundate     SampleID   Gene  \
# 0       14/04/2023  R2303061875   SDHB
# 1       14/04/2023  R2303061875   SDHB
# 2       14/04/2023  R2303061875   SDHB
# 3       14/04/2023  R2303061875   SDHB
# 4       14/04/2023  R2303061875  MUTYH
# ...            ...          ...    ...
# 162647  17/01/2024  R2401062088  CHEK2
# 162648  17/01/2024  R2401062088  CHEK2
# 162649  17/01/2024  R2401062088  CHEK2
# 162650  17/01/2024  R2401062088  CHEK2
# 162651  17/01/2024  R2401062088  CHEK2
#
#                                     Nucleotide [AAchange]    dbSNP ID  \
# 0             g.chr1:17032891T>C|NM_003000|c.e3-169A>G|--
# 1             g.chr1:17044657T>C|NM_003000|c.e2-104A>G|--
# 2             g.chr1:17044999C>T|NM_003000|c.e2+111G>A|--
# 3              g.chr1:17054002G>T|NM_003000|c.18C>A|p.A6A   rs2746462
# 4         g.chr1:45330597G>C|NM_001048171|c.e3+1160C>G|--   rs3219493
# ...                                                   ...         ...
# 162647   g.chr22:28694987C>G|NM_001005735|c.e13-140G>C|--  rs17886236
# 162648    g.chr22:28695049G>C|NM_001005735|c.e13-78C>G|--
# 162649    g.chr22:28703766T>C|NM_001005735|c.e9+200A>G|--
# 162650     g.chr22:28734312C>T|NM_001005735|c.e3-91G>A|--
# 162651  g.chr22:28734825_28734826insA|NM_001005735|c.e...
#
#        Chromosome     Start       End Ref Alt Variant Type  \
# 0            chr1  17032891  17032891   T   C          SNP
# 1            chr1  17044657  17044657   T   C          SNP
# 2            chr1  17044999  17044999   C   T          SNP
# 3            chr1  17054002  17054002   G   T          SNP
# 4            chr1  45330597  45330597   G   C          SNP
# ...           ...       ...       ...  ..  ..          ...
# 162647      chr22  28694987  28694987   C   G          SNP
# 162648      chr22  28695049  28695049   G   C          SNP
# 162649      chr22  28703766  28703766   T   C          SNP
# 162650      chr22  28734312  28734312   C   T          SNP
# 162651      chr22  28734825  28734826   -   A          INS
#
#        Variant_Classification     VAF Genotype  alt_count  ref_count   DP  \
# 0                      Intron   49.74      Het         96         97  193
# 1                      Intron   45.91      Het         73         86  159
# 2                      Intron   44.70      Het         97        120  217
# 3                      Silent   99.66   HomAlt        876          3  879
# 4                      Intron  100.00   HomAlt        545          0  545
# ...                       ...     ...      ...        ...        ...  ...
# 162647                 Intron   68.18      Het         30         14   44
# 162648                 Intron   58.62      Het         51         36   87
# 162649                 Intron   46.67      Het          7          8   15
# 162650                 Intron   31.71      Het         13         28   41
# 162651                 Intron   50.00      Het         13         13   26
#
#        Clinical Relevance   P/LP_Result Mode_of_Inheritance  \
# 0                          not detected                  AD
# 1                          not detected                  AD
# 2                          not detected                  AD
# 3                  Benign  not detected                  AD
# 4                  Benign  not detected                  AR
# ...                   ...           ...                 ...
# 162647      Likely_benign  not detected
# 162648                     not detected
# 162649                     not detected
# 162650                     not detected
# 162651                     not detected
#
#                          Disease_Name
# 0       Paragangliomas 4 (MIM 115310)
# 1       Paragangliomas 4 (MIM 115310)
# 2       Paragangliomas 4 (MIM 115310)
# 3       Paragangliomas 4 (MIM 115310)
# 4          Pilomatrixoma (MIM 132600)
# ...                               ...
# 162647
# 162648
# 162649
# 162650
# 162651
#
# [162652 rows x 21 columns]

# %%
bahan_db_df
# Out:
#            Rundate     SampleID   Gene  \
# 0       14/04/2023  R2303061875   SDHB
# 1       14/04/2023  R2303061875   SDHB
# 2       14/04/2023  R2303061875   SDHB
# 3       14/04/2023  R2303061875   SDHB
# 4       14/04/2023  R2303061875  MUTYH
# ...            ...          ...    ...
# 162647  17/01/2024  R2401062088  CHEK2
# 162648  17/01/2024  R2401062088  CHEK2
# 162649  17/01/2024  R2401062088  CHEK2
# 162650  17/01/2024  R2401062088  CHEK2
# 162651  17/01/2024  R2401062088  CHEK2
#
#                                     Nucleotide [AAchange]    dbSNP ID  \
# 0             g.chr1:17032891T>C|NM_003000|c.e3-169A>G|--
# 1             g.chr1:17044657T>C|NM_003000|c.e2-104A>G|--
# 2             g.chr1:17044999C>T|NM_003000|c.e2+111G>A|--
# 3              g.chr1:17054002G>T|NM_003000|c.18C>A|p.A6A   rs2746462
# 4         g.chr1:45330597G>C|NM_001048171|c.e3+1160C>G|--   rs3219493
# ...                                                   ...         ...
# 162647   g.chr22:28694987C>G|NM_001005735|c.e13-140G>C|--  rs17886236
# 162648    g.chr22:28695049G>C|NM_001005735|c.e13-78C>G|--
# 162649    g.chr22:28703766T>C|NM_001005735|c.e9+200A>G|--
# 162650     g.chr22:28734312C>T|NM_001005735|c.e3-91G>A|--
# 162651  g.chr22:28734825_28734826insA|NM_001005735|c.e...
#
#        Chromosome     Start       End Ref Alt Variant Type  \
# 0            chr1  17032891  17032891   T   C          SNP
# 1            chr1  17044657  17044657   T   C          SNP
# 2            chr1  17044999  17044999   C   T          SNP
# 3            chr1  17054002  17054002   G   T          SNP
# 4            chr1  45330597  45330597   G   C          SNP
# ...           ...       ...       ...  ..  ..          ...
# 162647      chr22  28694987  28694987   C   G          SNP
# 162648      chr22  28695049  28695049   G   C          SNP
# 162649      chr22  28703766  28703766   T   C          SNP
# 162650      chr22  28734312  28734312   C   T          SNP
# 162651      chr22  28734825  28734826   -   A          INS
#
#        Variant_Classification     VAF Genotype  alt_count  ref_count   DP  \
# 0                      Intron   49.74      Het         96         97  193
# 1                      Intron   45.91      Het         73         86  159
# 2                      Intron   44.70      Het         97        120  217
# 3                      Silent   99.66   HomAlt        876          3  879
# 4                      Intron  100.00   HomAlt        545          0  545
# ...                       ...     ...      ...        ...        ...  ...
# 162647                 Intron   68.18      Het         30         14   44
# 162648                 Intron   58.62      Het         51         36   87
# 162649                 Intron   46.67      Het          7          8   15
# 162650                 Intron   31.71      Het         13         28   41
# 162651                 Intron   50.00      Het         13         13   26
#
#        Clinical Relevance   P/LP_Result Mode_of_Inheritance  \
# 0                          not detected                  AD
# 1                          not detected                  AD
# 2                          not detected                  AD
# 3                  Benign  not detected                  AD
# 4                  Benign  not detected                  AR
# ...                   ...           ...                 ...
# 162647      Likely_benign  not detected
# 162648                     not detected
# 162649                     not detected
# 162650                     not detected
# 162651                     not detected
#
#                          Disease_Name
# 0       Paragangliomas 4 (MIM 115310)
# 1       Paragangliomas 4 (MIM 115310)
# 2       Paragangliomas 4 (MIM 115310)
# 3       Paragangliomas 4 (MIM 115310)
# 4          Pilomatrixoma (MIM 132600)
# ...                               ...
# 162647
# 162648
# 162649
# 162650
# 162651
#
# [162652 rows x 21 columns]

# %%
bahan_db_df.rename(columns={'Disease_Name': 'Disease Name'}, inplace=True)
all_columns = bahan_db_df.columns
desired_columns = ['Rundate','SampleID','Nucleotide [AAchange]', 'Clinical Relevance', 'Disease Name', 'Chromosome', 'dbSNP ID']
new_column_order = [col for col in desired_columns if col in all_columns] + [col for col in all_columns if col not in desired_columns]
new_column_order
bahan_db_df = bahan_db_df[new_column_order]
bahan_db_df
# Out:
#            Rundate     SampleID  \
# 0       14/04/2023  R2303061875
# 1       14/04/2023  R2303061875
# 2       14/04/2023  R2303061875
# 3       14/04/2023  R2303061875
# 4       14/04/2023  R2303061875
# ...            ...          ...
# 162647  17/01/2024  R2401062088
# 162648  17/01/2024  R2401062088
# 162649  17/01/2024  R2401062088
# 162650  17/01/2024  R2401062088
# 162651  17/01/2024  R2401062088
#
#                                     Nucleotide [AAchange] Clinical Relevance  \
# 0             g.chr1:17032891T>C|NM_003000|c.e3-169A>G|--
# 1             g.chr1:17044657T>C|NM_003000|c.e2-104A>G|--
# 2             g.chr1:17044999C>T|NM_003000|c.e2+111G>A|--
# 3              g.chr1:17054002G>T|NM_003000|c.18C>A|p.A6A             Benign
# 4         g.chr1:45330597G>C|NM_001048171|c.e3+1160C>G|--             Benign
# ...                                                   ...                ...
# 162647   g.chr22:28694987C>G|NM_001005735|c.e13-140G>C|--      Likely_benign
# 162648    g.chr22:28695049G>C|NM_001005735|c.e13-78C>G|--
# 162649    g.chr22:28703766T>C|NM_001005735|c.e9+200A>G|--
# 162650     g.chr22:28734312C>T|NM_001005735|c.e3-91G>A|--
# 162651  g.chr22:28734825_28734826insA|NM_001005735|c.e...
#
#                          Disease Name Chromosome    dbSNP ID   Gene     Start  \
# 0       Paragangliomas 4 (MIM 115310)       chr1               SDHB  17032891
# 1       Paragangliomas 4 (MIM 115310)       chr1               SDHB  17044657
# 2       Paragangliomas 4 (MIM 115310)       chr1               SDHB  17044999
# 3       Paragangliomas 4 (MIM 115310)       chr1   rs2746462   SDHB  17054002
# 4          Pilomatrixoma (MIM 132600)       chr1   rs3219493  MUTYH  45330597
# ...                               ...        ...         ...    ...       ...
# 162647                                     chr22  rs17886236  CHEK2  28694987
# 162648                                     chr22              CHEK2  28695049
# 162649                                     chr22              CHEK2  28703766
# 162650                                     chr22              CHEK2  28734312
# 162651                                     chr22              CHEK2  28734825
#
#              End Ref Alt Variant Type Variant_Classification     VAF Genotype  \
# 0       17032891   T   C          SNP                 Intron   49.74      Het
# 1       17044657   T   C          SNP                 Intron   45.91      Het
# 2       17044999   C   T          SNP                 Intron   44.70      Het
# 3       17054002   G   T          SNP                 Silent   99.66   HomAlt
# 4       45330597   G   C          SNP                 Intron  100.00   HomAlt
# ...          ...  ..  ..          ...                    ...     ...      ...
# 162647  28694987   C   G          SNP                 Intron   68.18      Het
# 162648  28695049   G   C          SNP                 Intron   58.62      Het
# 162649  28703766   T   C          SNP                 Intron   46.67      Het
# 162650  28734312   C   T          SNP                 Intron   31.71      Het
# 162651  28734826   -   A          INS                 Intron   50.00      Het
#
#         alt_count  ref_count   DP   P/LP_Result Mode_of_Inheritance
# 0              96         97  193  not detected                  AD
# 1              73         86  159  not detected                  AD
# 2              97        120  217  not detected                  AD
# 3             876          3  879  not detected                  AD
# 4             545          0  545  not detected                  AR
# ...           ...        ...  ...           ...                 ...
# 162647         30         14   44  not detected
# 162648         51         36   87  not detected
# 162649          7          8   15  not detected
# 162650         13         28   41  not detected
# 162651         13         13   26  not detected
#
# [162652 rows x 21 columns]

# %%
# Convert the 'Date' column to datetime format using the 'dayfirst' parameter
bahan_db_df['Rundate'] = pd.to_datetime(bahan_db_df['Rundate'], dayfirst=True)

# Convert the datetime objects back to strings in the desired format
bahan_db_df['Rundate'] = bahan_db_df['Rundate'].dt.strftime('%Y/%m/%d')

bahan_db_df
# Out:
#            Rundate     SampleID  \
# 0       2023/04/14  R2303061875
# 1       2023/04/14  R2303061875
# 2       2023/04/14  R2303061875
# 3       2023/04/14  R2303061875
# 4       2023/04/14  R2303061875
# ...            ...          ...
# 162647  2024/01/17  R2401062088
# 162648  2024/01/17  R2401062088
# 162649  2024/01/17  R2401062088
# 162650  2024/01/17  R2401062088
# 162651  2024/01/17  R2401062088
#
#                                     Nucleotide [AAchange] Clinical Relevance  \
# 0             g.chr1:17032891T>C|NM_003000|c.e3-169A>G|--
# 1             g.chr1:17044657T>C|NM_003000|c.e2-104A>G|--
# 2             g.chr1:17044999C>T|NM_003000|c.e2+111G>A|--
# 3              g.chr1:17054002G>T|NM_003000|c.18C>A|p.A6A             Benign
# 4         g.chr1:45330597G>C|NM_001048171|c.e3+1160C>G|--             Benign
# ...                                                   ...                ...
# 162647   g.chr22:28694987C>G|NM_001005735|c.e13-140G>C|--      Likely_benign
# 162648    g.chr22:28695049G>C|NM_001005735|c.e13-78C>G|--
# 162649    g.chr22:28703766T>C|NM_001005735|c.e9+200A>G|--
# 162650     g.chr22:28734312C>T|NM_001005735|c.e3-91G>A|--
# 162651  g.chr22:28734825_28734826insA|NM_001005735|c.e...
#
#                          Disease Name Chromosome    dbSNP ID   Gene     Start  \
# 0       Paragangliomas 4 (MIM 115310)       chr1               SDHB  17032891
# 1       Paragangliomas 4 (MIM 115310)       chr1               SDHB  17044657
# 2       Paragangliomas 4 (MIM 115310)       chr1               SDHB  17044999
# 3       Paragangliomas 4 (MIM 115310)       chr1   rs2746462   SDHB  17054002
# 4          Pilomatrixoma (MIM 132600)       chr1   rs3219493  MUTYH  45330597
# ...                               ...        ...         ...    ...       ...
# 162647                                     chr22  rs17886236  CHEK2  28694987
# 162648                                     chr22              CHEK2  28695049
# 162649                                     chr22              CHEK2  28703766
# 162650                                     chr22              CHEK2  28734312
# 162651                                     chr22              CHEK2  28734825
#
#              End Ref Alt Variant Type Variant_Classification     VAF Genotype  \
# 0       17032891   T   C          SNP                 Intron   49.74      Het
# 1       17044657   T   C          SNP                 Intron   45.91      Het
# 2       17044999   C   T          SNP                 Intron   44.70      Het
# 3       17054002   G   T          SNP                 Silent   99.66   HomAlt
# 4       45330597   G   C          SNP                 Intron  100.00   HomAlt
# ...          ...  ..  ..          ...                    ...     ...      ...
# 162647  28694987   C   G          SNP                 Intron   68.18      Het
# 162648  28695049   G   C          SNP                 Intron   58.62      Het
# 162649  28703766   T   C          SNP                 Intron   46.67      Het
# 162650  28734312   C   T          SNP                 Intron   31.71      Het
# 162651  28734826   -   A          INS                 Intron   50.00      Het
#
#         alt_count  ref_count   DP   P/LP_Result Mode_of_Inheritance
# 0              96         97  193  not detected                  AD
# 1              73         86  159  not detected                  AD
# 2              97        120  217  not detected                  AD
# 3             876          3  879  not detected                  AD
# 4             545          0  545  not detected                  AR
# ...           ...        ...  ...           ...                 ...
# 162647         30         14   44  not detected
# 162648         51         36   87  not detected
# 162649          7          8   15  not detected
# 162650         13         28   41  not detected
# 162651         13         13   26  not detected
#
# [162652 rows x 21 columns]

# %%
bahan_db_df['Variant_Record'] = bahan_db_df.apply(lambda row: generate_unique_id(row['Rundate'] + ' | ' + row['SampleID'] + ' | ' + row['Nucleotide [AAchange]']), axis=1)
bahan_db_df
# Out:
#            Rundate     SampleID  \
# 0       2023/04/14  R2303061875
# 1       2023/04/14  R2303061875
# 2       2023/04/14  R2303061875
# 3       2023/04/14  R2303061875
# 4       2023/04/14  R2303061875
# ...            ...          ...
# 162647  2024/01/17  R2401062088
# 162648  2024/01/17  R2401062088
# 162649  2024/01/17  R2401062088
# 162650  2024/01/17  R2401062088
# 162651  2024/01/17  R2401062088
#
#                                     Nucleotide [AAchange] Clinical Relevance  \
# 0             g.chr1:17032891T>C|NM_003000|c.e3-169A>G|--
# 1             g.chr1:17044657T>C|NM_003000|c.e2-104A>G|--
# 2             g.chr1:17044999C>T|NM_003000|c.e2+111G>A|--
# 3              g.chr1:17054002G>T|NM_003000|c.18C>A|p.A6A             Benign
# 4         g.chr1:45330597G>C|NM_001048171|c.e3+1160C>G|--             Benign
# ...                                                   ...                ...
# 162647   g.chr22:28694987C>G|NM_001005735|c.e13-140G>C|--      Likely_benign
# 162648    g.chr22:28695049G>C|NM_001005735|c.e13-78C>G|--
# 162649    g.chr22:28703766T>C|NM_001005735|c.e9+200A>G|--
# 162650     g.chr22:28734312C>T|NM_001005735|c.e3-91G>A|--
# 162651  g.chr22:28734825_28734826insA|NM_001005735|c.e...
#
#                          Disease Name Chromosome    dbSNP ID   Gene     Start  \
# 0       Paragangliomas 4 (MIM 115310)       chr1               SDHB  17032891
# 1       Paragangliomas 4 (MIM 115310)       chr1               SDHB  17044657
# 2       Paragangliomas 4 (MIM 115310)       chr1               SDHB  17044999
# 3       Paragangliomas 4 (MIM 115310)       chr1   rs2746462   SDHB  17054002
# 4          Pilomatrixoma (MIM 132600)       chr1   rs3219493  MUTYH  45330597
# ...                               ...        ...         ...    ...       ...
# 162647                                     chr22  rs17886236  CHEK2  28694987
# 162648                                     chr22              CHEK2  28695049
# 162649                                     chr22              CHEK2  28703766
# 162650                                     chr22              CHEK2  28734312
# 162651                                     chr22              CHEK2  28734825
#
#              End Ref Alt Variant Type Variant_Classification     VAF Genotype  \
# 0       17032891   T   C          SNP                 Intron   49.74      Het
# 1       17044657   T   C          SNP                 Intron   45.91      Het
# 2       17044999   C   T          SNP                 Intron   44.70      Het
# 3       17054002   G   T          SNP                 Silent   99.66   HomAlt
# 4       45330597   G   C          SNP                 Intron  100.00   HomAlt
# ...          ...  ..  ..          ...                    ...     ...      ...
# 162647  28694987   C   G          SNP                 Intron   68.18      Het
# 162648  28695049   G   C          SNP                 Intron   58.62      Het
# 162649  28703766   T   C          SNP                 Intron   46.67      Het
# 162650  28734312   C   T          SNP                 Intron   31.71      Het
# 162651  28734826   -   A          INS                 Intron   50.00      Het
#
#         alt_count  ref_count   DP   P/LP_Result Mode_of_Inheritance  \
# 0              96         97  193  not detected                  AD
# 1              73         86  159  not detected                  AD
# 2              97        120  217  not detected                  AD
# 3             876          3  879  not detected                  AD
# 4             545          0  545  not detected                  AR
# ...           ...        ...  ...           ...                 ...
# 162647         30         14   44  not detected
# 162648         51         36   87  not detected
# 162649          7          8   15  not detected
# 162650         13         28   41  not detected
# 162651         13         13   26  not detected
#
#                                            Variant_Record
# 0       4033732064895249566743264043910700766358748819...
# 1       7632571583479047278483398426095059141725570125...
# 2       6907276342077659380266749093569215599901803182...
# 3       4902072944153808316336709269360209722627911761...
# 4       3699264021093677716908640236982176456640991531...
# ...                                                   ...
# 162647  1117162511062382013085127344423789318027129222...
# 162648  7677422902686165563271874220330511463706534026...
# 162649  2095887827705408984261745191950751689122712668...
# 162650  1560944849085526669941227313946901905251088020...
# 162651  3485652128672047435273636722318682603382369613...
#
# [162652 rows x 22 columns]

# %%
bahan_db_df
# Out:
#            Rundate     SampleID  \
# 0       2023/04/14  R2303061875
# 1       2023/04/14  R2303061875
# 2       2023/04/14  R2303061875
# 3       2023/04/14  R2303061875
# 4       2023/04/14  R2303061875
# ...            ...          ...
# 162647  2024/01/17  R2401062088
# 162648  2024/01/17  R2401062088
# 162649  2024/01/17  R2401062088
# 162650  2024/01/17  R2401062088
# 162651  2024/01/17  R2401062088
#
#                                     Nucleotide [AAchange] Clinical Relevance  \
# 0             g.chr1:17032891T>C|NM_003000|c.e3-169A>G|--
# 1             g.chr1:17044657T>C|NM_003000|c.e2-104A>G|--
# 2             g.chr1:17044999C>T|NM_003000|c.e2+111G>A|--
# 3              g.chr1:17054002G>T|NM_003000|c.18C>A|p.A6A             Benign
# 4         g.chr1:45330597G>C|NM_001048171|c.e3+1160C>G|--             Benign
# ...                                                   ...                ...
# 162647   g.chr22:28694987C>G|NM_001005735|c.e13-140G>C|--      Likely_benign
# 162648    g.chr22:28695049G>C|NM_001005735|c.e13-78C>G|--
# 162649    g.chr22:28703766T>C|NM_001005735|c.e9+200A>G|--
# 162650     g.chr22:28734312C>T|NM_001005735|c.e3-91G>A|--
# 162651  g.chr22:28734825_28734826insA|NM_001005735|c.e...
#
#                          Disease Name Chromosome    dbSNP ID   Gene     Start  \
# 0       Paragangliomas 4 (MIM 115310)       chr1               SDHB  17032891
# 1       Paragangliomas 4 (MIM 115310)       chr1               SDHB  17044657
# 2       Paragangliomas 4 (MIM 115310)       chr1               SDHB  17044999
# 3       Paragangliomas 4 (MIM 115310)       chr1   rs2746462   SDHB  17054002
# 4          Pilomatrixoma (MIM 132600)       chr1   rs3219493  MUTYH  45330597
# ...                               ...        ...         ...    ...       ...
# 162647                                     chr22  rs17886236  CHEK2  28694987
# 162648                                     chr22              CHEK2  28695049
# 162649                                     chr22              CHEK2  28703766
# 162650                                     chr22              CHEK2  28734312
# 162651                                     chr22              CHEK2  28734825
#
#              End Ref Alt Variant Type Variant_Classification     VAF Genotype  \
# 0       17032891   T   C          SNP                 Intron   49.74      Het
# 1       17044657   T   C          SNP                 Intron   45.91      Het
# 2       17044999   C   T          SNP                 Intron   44.70      Het
# 3       17054002   G   T          SNP                 Silent   99.66   HomAlt
# 4       45330597   G   C          SNP                 Intron  100.00   HomAlt
# ...          ...  ..  ..          ...                    ...     ...      ...
# 162647  28694987   C   G          SNP                 Intron   68.18      Het
# 162648  28695049   G   C          SNP                 Intron   58.62      Het
# 162649  28703766   T   C          SNP                 Intron   46.67      Het
# 162650  28734312   C   T          SNP                 Intron   31.71      Het
# 162651  28734826   -   A          INS                 Intron   50.00      Het
#
#         alt_count  ref_count   DP   P/LP_Result Mode_of_Inheritance  \
# 0              96         97  193  not detected                  AD
# 1              73         86  159  not detected                  AD
# 2              97        120  217  not detected                  AD
# 3             876          3  879  not detected                  AD
# 4             545          0  545  not detected                  AR
# ...           ...        ...  ...           ...                 ...
# 162647         30         14   44  not detected
# 162648         51         36   87  not detected
# 162649          7          8   15  not detected
# 162650         13         28   41  not detected
# 162651         13         13   26  not detected
#
#                                            Variant_Record
# 0       4033732064895249566743264043910700766358748819...
# 1       7632571583479047278483398426095059141725570125...
# 2       6907276342077659380266749093569215599901803182...
# 3       4902072944153808316336709269360209722627911761...
# 4       3699264021093677716908640236982176456640991531...
# ...                                                   ...
# 162647  1117162511062382013085127344423789318027129222...
# 162648  7677422902686165563271874220330511463706534026...
# 162649  2095887827705408984261745191950751689122712668...
# 162650  1560944849085526669941227313946901905251088020...
# 162651  3485652128672047435273636722318682603382369613...
#
# [162652 rows x 22 columns]

# %%
bahan_db_df.at[0,'Variant_Record']
duplicate_rows_specific = bahan_db_df[bahan_db_df.duplicated(['Variant_Record'])]
print(duplicate_rows_specific)
# Out:
#            Rundate     SampleID  \
# 29274   2023/03/06  R2303041918
# 37462   2024/01/19  R2401131933
# 43808   2023/10/16  R2310100825
# 44194   2023/10/16  R2310121163
# 152620  2021/07/07         HCP1
# 152898  2021/07/07         HCP1
#
#                                    Nucleotide [AAchange] Clinical Relevance  \
# 29274   __UNKNOWN__|NM_001243998|__UNKNOWN__|__UNKNOWN__
# 37462      __UNKNOWN__|NM_000249|__UNKNOWN__|__UNKNOWN__
# 43808   __UNKNOWN__|NM_001126049|__UNKNOWN__|__UNKNOWN__             Benign
# 44194      __UNKNOWN__|NM_000249|__UNKNOWN__|__UNKNOWN__
# 152620                         __UNKNOWN__ [__UNKNOWN__]
# 152898                         __UNKNOWN__ [__UNKNOWN__]
#
#                         Disease Name   Chromosome   dbSNP ID         Gene  \
# 29274                                 __UNKNOWN__             __UNKNOWN__
# 37462   Lynch syndrome (MIM 120435)   __UNKNOWN__             __UNKNOWN__
# 43808                                 __UNKNOWN__  rs2943772  __UNKNOWN__
# 44194   Lynch syndrome (MIM 120435)   __UNKNOWN__             __UNKNOWN__
# 152620  Lynch syndrome (MIM 120435)   __UNKNOWN__             __UNKNOWN__
# 152898                                __UNKNOWN__             __UNKNOWN__
#
#               Start          End          Ref          Alt Variant Type  \
# 29274   __UNKNOWN__  __UNKNOWN__  __UNKNOWN__  __UNKNOWN__  __UNKNOWN__
# 37462   __UNKNOWN__  __UNKNOWN__  __UNKNOWN__  __UNKNOWN__  __UNKNOWN__
# 43808   __UNKNOWN__  __UNKNOWN__  __UNKNOWN__  __UNKNOWN__  __UNKNOWN__
# 44194   __UNKNOWN__  __UNKNOWN__  __UNKNOWN__  __UNKNOWN__  __UNKNOWN__
# 152620  __UNKNOWN__  __UNKNOWN__                            __UNKNOWN__
# 152898  __UNKNOWN__  __UNKNOWN__                            __UNKNOWN__
#
#        Variant_Classification     VAF Genotype  alt_count  ref_count   DP  \
# 29274             __UNKNOWN__  100.00   HomAlt          2          0    2
# 37462             __UNKNOWN__  100.00   HomAlt         10          0   10
# 43808             __UNKNOWN__  100.00   HomAlt         53          0   53
# 44194             __UNKNOWN__  100.00   HomAlt         14          0   14
# 152620            __UNKNOWN__   94.12   HomAlt         16          1  196
# 152898            __UNKNOWN__  100.00   HomAlt          3          0   12
#
#          P/LP_Result Mode_of_Inheritance  \
# 29274   not detected
# 37462   not detected                  AD
# 43808   not detected
# 44194   not detected                  AD
# 152620      detected                  AD
# 152898      detected
#
#                                            Variant_Record
# 29274   8154310245376185821562886404894591733365170785...
# 37462   9755085109107587011234098115848160271409611505...
# 43808   3976776801748119458805457232535362159087700947...
# 44194   2429434306197402874676997484355056785253788137...
# 152620  8136120995176728916552532255382322083062747056...
# 152898  8136120995176728916552532255382322083062747056...

# %%
final_column_name = {
    'Nucleotide [AAchange]':'Variant',
    'Clinical Relevance':'Clinical_Relevance',
    'Disease Name':'Disease_Name',
    'dbSNP ID':'dbSNP_ID',
    'Variant Type':'Variant_Type',
    'P/LP_Result':'P_LP_Result'
}
bahan_db_df.rename(columns=final_column_name, inplace=True)
bahan_db_df
# Out:
#            Rundate     SampleID  \
# 0       2023/04/14  R2303061875
# 1       2023/04/14  R2303061875
# 2       2023/04/14  R2303061875
# 3       2023/04/14  R2303061875
# 4       2023/04/14  R2303061875
# ...            ...          ...
# 162647  2024/01/17  R2401062088
# 162648  2024/01/17  R2401062088
# 162649  2024/01/17  R2401062088
# 162650  2024/01/17  R2401062088
# 162651  2024/01/17  R2401062088
#
#                                                   Variant Clinical_Relevance  \
# 0             g.chr1:17032891T>C|NM_003000|c.e3-169A>G|--
# 1             g.chr1:17044657T>C|NM_003000|c.e2-104A>G|--
# 2             g.chr1:17044999C>T|NM_003000|c.e2+111G>A|--
# 3              g.chr1:17054002G>T|NM_003000|c.18C>A|p.A6A             Benign
# 4         g.chr1:45330597G>C|NM_001048171|c.e3+1160C>G|--             Benign
# ...                                                   ...                ...
# 162647   g.chr22:28694987C>G|NM_001005735|c.e13-140G>C|--      Likely_benign
# 162648    g.chr22:28695049G>C|NM_001005735|c.e13-78C>G|--
# 162649    g.chr22:28703766T>C|NM_001005735|c.e9+200A>G|--
# 162650     g.chr22:28734312C>T|NM_001005735|c.e3-91G>A|--
# 162651  g.chr22:28734825_28734826insA|NM_001005735|c.e...
#
#                          Disease_Name Chromosome    dbSNP_ID   Gene     Start  \
# 0       Paragangliomas 4 (MIM 115310)       chr1               SDHB  17032891
# 1       Paragangliomas 4 (MIM 115310)       chr1               SDHB  17044657
# 2       Paragangliomas 4 (MIM 115310)       chr1               SDHB  17044999
# 3       Paragangliomas 4 (MIM 115310)       chr1   rs2746462   SDHB  17054002
# 4          Pilomatrixoma (MIM 132600)       chr1   rs3219493  MUTYH  45330597
# ...                               ...        ...         ...    ...       ...
# 162647                                     chr22  rs17886236  CHEK2  28694987
# 162648                                     chr22              CHEK2  28695049
# 162649                                     chr22              CHEK2  28703766
# 162650                                     chr22              CHEK2  28734312
# 162651                                     chr22              CHEK2  28734825
#
#              End Ref Alt Variant_Type Variant_Classification     VAF Genotype  \
# 0       17032891   T   C          SNP                 Intron   49.74      Het
# 1       17044657   T   C          SNP                 Intron   45.91      Het
# 2       17044999   C   T          SNP                 Intron   44.70      Het
# 3       17054002   G   T          SNP                 Silent   99.66   HomAlt
# 4       45330597   G   C          SNP                 Intron  100.00   HomAlt
# ...          ...  ..  ..          ...                    ...     ...      ...
# 162647  28694987   C   G          SNP                 Intron   68.18      Het
# 162648  28695049   G   C          SNP                 Intron   58.62      Het
# 162649  28703766   T   C          SNP                 Intron   46.67      Het
# 162650  28734312   C   T          SNP                 Intron   31.71      Het
# 162651  28734826   -   A          INS                 Intron   50.00      Het
#
#         alt_count  ref_count   DP   P_LP_Result Mode_of_Inheritance  \
# 0              96         97  193  not detected                  AD
# 1              73         86  159  not detected                  AD
# 2              97        120  217  not detected                  AD
# 3             876          3  879  not detected                  AD
# 4             545          0  545  not detected                  AR
# ...           ...        ...  ...           ...                 ...
# 162647         30         14   44  not detected
# 162648         51         36   87  not detected
# 162649          7          8   15  not detected
# 162650         13         28   41  not detected
# 162651         13         13   26  not detected
#
#                                            Variant_Record
# 0       4033732064895249566743264043910700766358748819...
# 1       7632571583479047278483398426095059141725570125...
# 2       6907276342077659380266749093569215599901803182...
# 3       4902072944153808316336709269360209722627911761...
# 4       3699264021093677716908640236982176456640991531...
# ...                                                   ...
# 162647  1117162511062382013085127344423789318027129222...
# 162648  7677422902686165563271874220330511463706534026...
# 162649  2095887827705408984261745191950751689122712668...
# 162650  1560944849085526669941227313946901905251088020...
# 162651  3485652128672047435273636722318682603382369613...
#
# [162652 rows x 22 columns]

# %%
# SQL statement for creating a table
create_table_sql1 = f"""
CREATE TABLE IF NOT EXISTS {table_name1} (
    `Rundate` TEXT,
    `SampleID` TEXT,
    `Variant` TEXT,
    `Clinical_Relevance` TEXT,
    `Disease_Name` TEXT,
    `Chromosome` TEXT,
    `dbSNP_ID` TEXT,
    `Gene` TEXT,
    `Start` TEXT,
    `End` TEXT,
    `Ref` TEXT,
    `Alt` TEXT,
    `Variant_Type` TEXT,
    `Variant_Classification` TEXT,
    `VAF` TEXT,
    `Genotype` TEXT,
    `alt_count` TEXT,
    `ref_count` TEXT,
    `DP` TEXT,
    `P_LP_Result` TEXT,
    `Mode_of_Inheritance` TEXT,
    `Variant_Record` TEXT PRIMARY KEY
);
"""

# SQL statement for creating a table
create_table_sql2 = f"""
CREATE TABLE IF NOT EXISTS {table_name2} (
    `version_id` INTEGER PRIMARY KEY AUTOINCREMENT,
    `Rundate` TEXT,
    `SampleID` TEXT,
    `Variant` TEXT,
    `Clinical_Relevance` TEXT,
    `Disease_Name` TEXT,
    `Chromosome` TEXT,
    `dbSNP_ID` TEXT,
    `Gene` TEXT,
    `Start` TEXT,
    `End` TEXT,
    `Ref` TEXT,
    `Alt` TEXT,
    `Variant_Type` TEXT,
    `Variant_Classification` TEXT,
    `VAF` TEXT,
    `Genotype` TEXT,
    `alt_count` TEXT,
    `ref_count` TEXT,
    `DP` TEXT,
    `P_LP_Result` TEXT,
    `Mode_of_Inheritance` TEXT,
    `Variant_Record` TEXT,
    `changed_by` TEXT,
    `change_date` TIMESTAMP DEFAULT CURRENT_TIMESTAMP,
    FOREIGN KEY(`Variant_Record`) REFERENCES {table_name1} (`Variant_Record`)
);
"""

# %%
import pandas as pd
import sqlite3


vava_db_dir = '/home/sysadmin/vava_db/'
database_file = 'TSHCvar.db'


# Remove duplicates based on the 'Variant Record' column, keeping the first occurrence
df_unique = bahan_db_df.drop_duplicates(subset=['Variant_Record'], keep='first')


table_name1 = 'db_var'
table_name2 = 'db_var_version_history'

# Replace 'your_database.sqlite' with the path to your SQLite file
db_path = f'{vava_db_dir}/{database_file}'

# Connect to the SQLite database
conn = sqlite3.connect(db_path)
cursor = conn.cursor()



# Execute the SQL statement to create the table
cursor.execute(create_table_sql1)
cursor.execute(create_table_sql2)

# Insert the deduplicated data into the SQL table
df_unique.to_sql(table_name1, conn, if_exists='append', index=False, method='multi', chunksize=500)

# Verify insertion by querying the first 5 rows
cursor.execute(f"SELECT * FROM {table_name1} LIMIT 5;")
rows = cursor.fetchall()

# Display the first 5 rows from the database for verification
for row in rows:
    print(row)

# Verify insertion by querying the first 5 rows
cursor.execute(f"SELECT * FROM {table_name2} LIMIT 5;")
rows = cursor.fetchall()

# Display the first 5 rows from the database for verification
for row in rows:
    print(row)


# Close the connection to the database
conn.close()
# Out:
# ('2023/04/14', 'R2303061875', 'g.chr1:17032891T>C|NM_003000|c.e3-169A>G|--', ' ', 'Paragangliomas 4 (MIM 115310)', 'chr1', ' ', 'SDHB', '17032891', '17032891', 'T', 'C', 'SNP', 'Intron', '49.74', 'Het', '96', '97', '193', 'not detected', 'AD', '40337320648952495667432640439107007663587488191788217981741751870061962988587')
# ('2023/04/14', 'R2303061875', 'g.chr1:17044657T>C|NM_003000|c.e2-104A>G|--', ' ', 'Paragangliomas 4 (MIM 115310)', 'chr1', ' ', 'SDHB', '17044657', '17044657', 'T', 'C', 'SNP', 'Intron', '45.91', 'Het', '73', '86', '159', 'not detected', 'AD', '7632571583479047278483398426095059141725570125641311441897613403591148550905')
# ('2023/04/14', 'R2303061875', 'g.chr1:17044999C>T|NM_003000|c.e2+111G>A|--', ' ', 'Paragangliomas 4 (MIM 115310)', 'chr1', ' ', 'SDHB', '17044999', '17044999', 'C', 'T', 'SNP', 'Intron', '44.7', 'Het', '97', '120', '217', 'not detected', 'AD', '69072763420776593802667490935692155999018031822586539961196970907651305157646')
# ('2023/04/14', 'R2303061875', 'g.chr1:17054002G>T|NM_003000|c.18C>A|p.A6A', 'Benign', 'Paragangliomas 4 (MIM 115310)', 'chr1', 'rs2746462', 'SDHB', '17054002', '17054002', 'G', 'T', 'SNP', 'Silent', '99.66', 'HomAlt', '876', '3', '879', 'not detected', 'AD', '49020729441538083163367092693602097226279117613836441905661411210270365229035')
# ('2023/04/14', 'R2303061875', 'g.chr1:45330597G>C|NM_001048171|c.e3+1160C>G|--', 'Benign', 'Pilomatrixoma (MIM 132600)', 'chr1', 'rs3219493', 'MUTYH', '45330597', '45330597', 'G', 'C', 'SNP', 'Intron', '100.0', 'HomAlt', '545', '0', '545', 'not detected', 'AR', '36992640210936777169086402369821764566409915316346923331999745901548428032102')

# %%
import pandas as pd
import sqlite3


vava_db_dir = '/home/sysadmin/vava_db/'
database_file = 'TSHCvar_empty.db'


# Remove duplicates based on the 'Variant Record' column, keeping the first occurrence
df_unique = bahan_db_df.drop_duplicates(subset=['Variant_Record'], keep='first')
dummy_df = df_unique.head(1)
dummy_df

table_name1 = 'db_var'
table_name2 = 'db_var_version_history'

# Replace 'your_database.sqlite' with the path to your SQLite file
db_path = f'{vava_db_dir}/{database_file}'

# Connect to the SQLite database
conn = sqlite3.connect(db_path)
cursor = conn.cursor()


# Execute the SQL statement to create the table
cursor.execute(create_table_sql1)
cursor.execute(create_table_sql2)

# Insert the deduplicated data into the SQL table
dummy_df.to_sql(table_name1, conn, if_exists='append', index=False, method='multi', chunksize=500)

# Verify insertion by querying the first 5 rows
cursor.execute(f"SELECT * FROM {table_name1} LIMIT 5;")
rows = cursor.fetchall()

# Display the first 5 rows from the database for verification
for row in rows:
    print(row)

# Verify insertion by querying the first 5 rows
cursor.execute(f"SELECT * FROM {table_name2} LIMIT 5;")
rows = cursor.fetchall()

# Display the first 5 rows from the database for verification
for row in rows:
    print(row)


# Close the connection to the database
conn.close()
# Out:
# ('2023/04/14', 'R2303061875', 'g.chr1:17032891T>C|NM_003000|c.e3-169A>G|--', ' ', 'Paragangliomas 4 (MIM 115310)', 'chr1', ' ', 'SDHB', '17032891', '17032891', 'T', 'C', 'SNP', 'Intron', '49.74', 'Het', '96', '97', '193', 'not detected', 'AD', '40337320648952495667432640439107007663587488191788217981741751870061962988587')

# %%
save_to_excel('/mnt/mol/test_db.xlsx', dfs={'Sheet1':bahan_db_df})

# %%
`Rundate`, `SampleID`, `Nucleotide [AAchange]`, `Clinical Relevance`, `Disease Name`, `Chromosome`, `dbSNP ID`, `Gene`, `Start`, `End`, `Ref`, `Alt`, `Variant Type`, `Variant_Classification`, `VAF`, `Genotype`, `alt_count`, `ref_count`, `DP`, `P/LP_Result`, `Mode_of_Inheritance`, `Variant_Record`, `changed_by`
