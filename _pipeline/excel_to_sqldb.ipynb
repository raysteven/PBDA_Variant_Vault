# %%
# %cd /mnt/mol/Bioinfo_Applications/PBDA/PBDA_Variant_Vault/_pipeline
# Out:
# /mnt/mol/Bioinfo_Applications/PBDA/PBDA_Variant_Vault/_pipeline

# %%
import hashlib

def generate_unique_id(data):
    # Create a hash object
    hash_object = hashlib.sha256(data.encode())
    
    # Convert the hash to a hexadecimal string
    hex_dig = hash_object.hexdigest()
    
    # Convert hexadecimal to integer (you can also truncate this to fit your needs)
    unique_id = str(int(hex_dig, 16))
    
    return unique_id

# %%
import os
from PBTK import *
import pandas as pd
from sqlalchemy import create_engine, Column, String, MetaData, Table
import sqlite3

vava_db_dir = '.'


current_directory = os.getcwd()
# Get the parent directory
parent_directory = os.path.dirname(current_directory)
bahan_db = os.listdir(os.path.join(current_directory, 'bahan_db_brcas'))

bahan_db_df = pd.DataFrame()
bahan_db_df

# Loop through the files, read each into a DataFrame, and append it to the merged_df
for file in bahan_db:
    print(file)
    file_path = os.path.join(current_directory, 'bahan_db_brcas', file)
    df_temp = pd.read_excel(file_path, engine='openpyxl')
    bahan_db_df = pd.concat([bahan_db_df, df_temp], ignore_index=True)
# Out:
# ['Rekap_BRCA12_Somatic_MAF_20230828.xlsx',
#  'Rekap_BRCA12_Somatic_MAF_20231127.xlsx',
#  'Rekap_BRCA12_Somatic_MAF_20210820.xlsx',
#  'Rekap_BRCA12_Somatic_MAF_20240415.xlsx',
#  'Rekap_BRCA12_Somatic_MAF_20230123.xlsx',
#  'Rekap_BRCA12_Somatic_MAF_20240102.xlsx',
#  'Rekap_BRCA12_Somatic_MAF_20231023.xlsx',
#  'Rekap_BRCA12_Somatic_MAF_20240312.xlsx',
#  'Rekap_BRCA12_Somatic_MAF_20230228.xlsx',
#  'Rekap_BRCA12_Somatic_MAF_20240325.xlsx',
#  'Rekap_BRCA12_Somatic_MAF_20230612.xlsx',
#  'Rekap_BRCA12_Somatic_MAF_20210630.xlsx',
#  'Rekap_BRCA12_Somatic_MAF_20230724.xlsx',
#  'Rekap_BRCA12_Somatic_MAF_20240216.xlsx',
#  'Rekap_BRCA12_Somatic_MAF_20211125.xlsx',
#  'Rekap_BRCA12_Somatic_MAF_20230925.xlsx',
#  'Rekap_BRCA12_Somatic_MAF_20211026.xlsx',
#  'Rekap_BRCA12_Somatic_MAF_20230508.xlsx',
#  'Rekap_BRCA12_Somatic_MAF_20230814.xlsx',
#  'Rekap_BRCA12_Somatic_MAF_20210826.xlsx',
#  'Rekap_BRCA12_Somatic_MAF_20230313.xlsx',
#  'Rekap_BRCA12_Somatic_MAF_20230502.xlsx',
#  'Rekap_BRCA12_Somatic_MAF_20230913.xlsx',
#  'Rekap_BRCA12_Somatic_MAF_20230704.xlsx',
#  'Rekap_BRCA12_Somatic_MAF_20211117.xlsx',
#  'Rekap_BRCA12_Somatic_MAF_20230929.xlsx',
#  'Rekap_BRCA12_Somatic_MAF_20231009.xlsx',
#  'Rekap_BRCA12_Somatic_MAF_20230710.xlsx',
#  'Rekap_BRCA12_Somatic_MAF_20211022.xlsx',
#  'Rekap_BRCA12_Somatic_MAF_20230522.xlsx',
#  'Rekap_BRCA12_Somatic_MAF_20230412.xlsx',
#  'Rekap_BRCA12_Somatic_MAF_20210928.xlsx',
#  'Rekap_BRCA12_Somatic_MAF_20240226.xlsx',
#  'Rekap_BRCA12_Somatic_MAF_20230213.xlsx',
#  'Rekap_BRCA12_Somatic_MAF_20210616.xlsx']

# %%
# Out:
# Rekap_BRCA12_Somatic_MAF_20230828.xlsx
# Rekap_BRCA12_Somatic_MAF_20231127.xlsx
# Rekap_BRCA12_Somatic_MAF_20210820.xlsx
# Rekap_BRCA12_Somatic_MAF_20240415.xlsx
# Rekap_BRCA12_Somatic_MAF_20230123.xlsx
# Rekap_BRCA12_Somatic_MAF_20240102.xlsx
# Rekap_BRCA12_Somatic_MAF_20231023.xlsx
# Rekap_BRCA12_Somatic_MAF_20240312.xlsx
# Rekap_BRCA12_Somatic_MAF_20230228.xlsx
# Rekap_BRCA12_Somatic_MAF_20240325.xlsx
# Rekap_BRCA12_Somatic_MAF_20230612.xlsx
# Rekap_BRCA12_Somatic_MAF_20210630.xlsx
# Rekap_BRCA12_Somatic_MAF_20230724.xlsx
# Rekap_BRCA12_Somatic_MAF_20240216.xlsx
# Rekap_BRCA12_Somatic_MAF_20211125.xlsx
# Rekap_BRCA12_Somatic_MAF_20230925.xlsx
# Rekap_BRCA12_Somatic_MAF_20211026.xlsx
# Rekap_BRCA12_Somatic_MAF_20230508.xlsx
# Rekap_BRCA12_Somatic_MAF_20230814.xlsx
# Rekap_BRCA12_Somatic_MAF_20210826.xlsx
# Rekap_BRCA12_Somatic_MAF_20230313.xlsx
# Rekap_BRCA12_Somatic_MAF_20230502.xlsx
# Rekap_BRCA12_Somatic_MAF_20230913.xlsx
# Rekap_BRCA12_Somatic_MAF_20230704.xlsx
# Rekap_BRCA12_Somatic_MAF_20211117.xlsx
# Rekap_BRCA12_Somatic_MAF_20230929.xlsx
# Rekap_BRCA12_Somatic_MAF_20231009.xlsx
# Rekap_BRCA12_Somatic_MAF_20230710.xlsx
# Rekap_BRCA12_Somatic_MAF_20211022.xlsx
# Rekap_BRCA12_Somatic_MAF_20230522.xlsx
# Rekap_BRCA12_Somatic_MAF_20230412.xlsx
# Rekap_BRCA12_Somatic_MAF_20210928.xlsx
# Rekap_BRCA12_Somatic_MAF_20240226.xlsx
# Rekap_BRCA12_Somatic_MAF_20230213.xlsx
# Rekap_BRCA12_Somatic_MAF_20210616.xlsx

# %%
bahan_db_df
# Out:
#       Unnamed: 0     Rundate     SampleID   Gene  \
# 0            0.0  28/08/2023  R2308161706  BRCA2
# 1            3.0  28/08/2023  R2308161706  BRCA2
# 2            4.0  28/08/2023  R2308161706  BRCA2
# 3            6.0  28/08/2023  R2308161706  BRCA2
# 4            8.0  28/08/2023  R2308161706  BRCA2
# ...          ...         ...          ...    ...
# 4715       143.0  16/06/2021  R2106290759  BRCA1
# 4716       145.0  16/06/2021  R2106290759  BRCA1
# 4717       146.0  16/06/2021  R2106290759  BRCA1
# 4718       149.0  16/06/2021  R2106290759  BRCA1
# 4719       150.0  16/06/2021  R2106290759  BRCA1
#
#                                   Nucleotide [AAchange]  \
# 0     NM_000059|g.chr13:32329548C>T|NM_000059|c.e8+5...
# 1     NM_000059|g.chr13:32333399delT|NM_000059|c.e10...
# 2     NM_000059|g.chr13:32333398_32333399insT|NM_000...
# 3     NM_000059|g.chr13:32338162T>C|NM_000059|c.3807T>C
# 4     NM_000059|g.chr13:32338918A>G|NM_000059|c.4563A>G
# ...                                                 ...
# 4715  NM_007294|g.chr17:43104058_43104059delAA|c.e6-...
# 4716   NM_007294|g.chr17:43104058delA|c.e6-65TG>G|--|--
# 4717   NM_007294|g.chr17:43104071delA|c.e6-52TC>C|--|--
# 4718  NM_007294|g.chr17:43104070_43104071GA>AG|c.e6-...
# 4719     NM_007294|g.chr17:43106433A>T|c.e4-23T>A|--|--
#
#                                 Nucleotide [AAchange].1  \
# 0     NM_000059|g.chr13:32329548C>T|NM_000059|c.e8+5...
# 1     NM_000059|g.chr13:32333399delT|NM_000059|c.e10...
# 2     NM_000059|g.chr13:32333398_32333399insT|NM_000...
# 3     NM_000059|g.chr13:32338162T>C|NM_000059|c.3807T>C
# 4     NM_000059|g.chr13:32338918A>G|NM_000059|c.4563A>G
# ...                                                 ...
# 4715                                                NaN
# 4716                                                NaN
# 4717                                                NaN
# 4718                                                NaN
# 4719                                                NaN
#
#                      dbSNP ID Chromosome       Start         End  ...  \
# 0                   rs2126042      chr13  32329548.0  32329548.0  ...
# 1                 rs276174816      chr13  32333399.0  32333399.0  ...
# 2     rs587780560,rs864622682      chr13  32333398.0  32333399.0  ...
# 3                    rs543304      chr13  32338162.0  32338162.0  ...
# 4                    rs206075      chr13  32338918.0  32338918.0  ...
# ...                       ...        ...         ...         ...  ...
# 4715                      NaN      chr17  43104058.0  43104059.0  ...
# 4716                      NaN      chr17  43104058.0  43104058.0  ...
# 4717                      NaN      chr17  43104071.0  43104071.0  ...
# 4718                      NaN      chr17  43104070.0  43104071.0  ...
# 4719                rs8176128      chr17  43106433.0  43106433.0  ...
#
#      Variant_Classification     VAF Genotype alt_count  ref_count       DP  \
# 0                    Intron   50.40      Het   16969.0      16702  33671.0
# 1                    Intron   22.38      Het    3308.0      11475  14783.0
# 2                    Intron    9.20      Het    1163.0      11475  12638.0
# 3                    Silent   48.41      Het   11897.0      12679  24576.0
# 4                    Silent  100.00   HomAlt    3289.0          0   3289.0
# ...                     ...     ...      ...       ...        ...      ...
# 4715                 Intron   26.35      Het     185.0        517    702.0
# 4716                 Intron   33.12      Het     256.0        517    773.0
# 4717                 Intron   31.17      Het     303.0        669    972.0
# 4718                 Intron   12.20      Het      93.0        669    762.0
# 4719                 Intron    7.73      Het      15.0        179    194.0
#
#       Clinical Relevance P/LP_Result  Mode_of_Inheritance Disease_Name
# 0                 Benign    detected                  NaN          NaN
# 1                    NaN    detected                  NaN          NaN
# 2                    NaN    detected                  NaN          NaN
# 3                 Benign    detected                  NaN          NaN
# 4                 Benign    detected                  NaN          NaN
# ...                  ...         ...                  ...          ...
# 4715                 NaN    detected                  NaN          NaN
# 4716                 NaN    detected                  NaN          NaN
# 4717                 NaN    detected                  NaN          NaN
# 4718                 NaN    detected                  NaN          NaN
# 4719              Benign    detected                  NaN          NaN
#
# [4720 rows x 23 columns]

# %%
try:
    bahan_db_df = bahan_db_df.drop(columns='Unnamed: 0')
    bahan_db_df = bahan_db_df.drop(columns='Nucleotide [AAchange].1')
except:
    pass
bahan_db_df.dropna(subset=['Rundate'], inplace=True)
bahan_db_df.fillna(' ', inplace=True)
bahan_db_df
# Out:
# /tmp/ipykernel_388/1735848291.py:7: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value ' ' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   bahan_db_df.fillna(' ', inplace=True)
#          Rundate     SampleID   Gene  \
# 0     28/08/2023  R2308161706  BRCA2
# 1     28/08/2023  R2308161706  BRCA2
# 2     28/08/2023  R2308161706  BRCA2
# 3     28/08/2023  R2308161706  BRCA2
# 4     28/08/2023  R2308161706  BRCA2
# ...          ...          ...    ...
# 4715  16/06/2021  R2106290759  BRCA1
# 4716  16/06/2021  R2106290759  BRCA1
# 4717  16/06/2021  R2106290759  BRCA1
# 4718  16/06/2021  R2106290759  BRCA1
# 4719  16/06/2021  R2106290759  BRCA1
#
#                                   Nucleotide [AAchange]  \
# 0     NM_000059|g.chr13:32329548C>T|NM_000059|c.e8+5...
# 1     NM_000059|g.chr13:32333399delT|NM_000059|c.e10...
# 2     NM_000059|g.chr13:32333398_32333399insT|NM_000...
# 3     NM_000059|g.chr13:32338162T>C|NM_000059|c.3807T>C
# 4     NM_000059|g.chr13:32338918A>G|NM_000059|c.4563A>G
# ...                                                 ...
# 4715  NM_007294|g.chr17:43104058_43104059delAA|c.e6-...
# 4716   NM_007294|g.chr17:43104058delA|c.e6-65TG>G|--|--
# 4717   NM_007294|g.chr17:43104071delA|c.e6-52TC>C|--|--
# 4718  NM_007294|g.chr17:43104070_43104071GA>AG|c.e6-...
# 4719     NM_007294|g.chr17:43106433A>T|c.e4-23T>A|--|--
#
#                      dbSNP ID Chromosome       Start         End Ref Alt  ...  \
# 0                   rs2126042      chr13  32329548.0  32329548.0   C   T  ...
# 1                 rs276174816      chr13  32333399.0  32333399.0   T   -  ...
# 2     rs587780560,rs864622682      chr13  32333398.0  32333399.0   -   T  ...
# 3                    rs543304      chr13  32338162.0  32338162.0   T   C  ...
# 4                    rs206075      chr13  32338918.0  32338918.0   A   G  ...
# ...                       ...        ...         ...         ...  ..  ..  ...
# 4715                               chr17  43104058.0  43104059.0          ...
# 4716                               chr17  43104058.0  43104058.0          ...
# 4717                               chr17  43104071.0  43104071.0          ...
# 4718                               chr17  43104070.0  43104071.0          ...
# 4719                rs8176128      chr17  43106433.0  43106433.0          ...
#
#      Variant_Classification     VAF  Genotype alt_count  ref_count       DP  \
# 0                    Intron   50.40       Het   16969.0      16702  33671.0
# 1                    Intron   22.38       Het    3308.0      11475  14783.0
# 2                    Intron    9.20       Het    1163.0      11475  12638.0
# 3                    Silent   48.41       Het   11897.0      12679  24576.0
# 4                    Silent  100.00    HomAlt    3289.0          0   3289.0
# ...                     ...     ...       ...       ...        ...      ...
# 4715                 Intron   26.35       Het     185.0        517    702.0
# 4716                 Intron   33.12       Het     256.0        517    773.0
# 4717                 Intron   31.17       Het     303.0        669    972.0
# 4718                 Intron   12.20       Het      93.0        669    762.0
# 4719                 Intron    7.73       Het      15.0        179    194.0
#
#       Clinical Relevance P/LP_Result Mode_of_Inheritance Disease_Name
# 0                 Benign    detected
# 1                           detected
# 2                           detected
# 3                 Benign    detected
# 4                 Benign    detected
# ...                  ...         ...                 ...          ...
# 4715                        detected
# 4716                        detected
# 4717                        detected
# 4718                        detected
# 4719              Benign    detected
#
# [4711 rows x 21 columns]

# %%
bahan_db_df
# Out:
#          Rundate     SampleID   Gene  \
# 0     28/08/2023  R2308161706  BRCA2
# 1     28/08/2023  R2308161706  BRCA2
# 2     28/08/2023  R2308161706  BRCA2
# 3     28/08/2023  R2308161706  BRCA2
# 4     28/08/2023  R2308161706  BRCA2
# ...          ...          ...    ...
# 4715  16/06/2021  R2106290759  BRCA1
# 4716  16/06/2021  R2106290759  BRCA1
# 4717  16/06/2021  R2106290759  BRCA1
# 4718  16/06/2021  R2106290759  BRCA1
# 4719  16/06/2021  R2106290759  BRCA1
#
#                                   Nucleotide [AAchange]  \
# 0     NM_000059|g.chr13:32329548C>T|NM_000059|c.e8+5...
# 1     NM_000059|g.chr13:32333399delT|NM_000059|c.e10...
# 2     NM_000059|g.chr13:32333398_32333399insT|NM_000...
# 3     NM_000059|g.chr13:32338162T>C|NM_000059|c.3807T>C
# 4     NM_000059|g.chr13:32338918A>G|NM_000059|c.4563A>G
# ...                                                 ...
# 4715  NM_007294|g.chr17:43104058_43104059delAA|c.e6-...
# 4716   NM_007294|g.chr17:43104058delA|c.e6-65TG>G|--|--
# 4717   NM_007294|g.chr17:43104071delA|c.e6-52TC>C|--|--
# 4718  NM_007294|g.chr17:43104070_43104071GA>AG|c.e6-...
# 4719     NM_007294|g.chr17:43106433A>T|c.e4-23T>A|--|--
#
#                      dbSNP ID Chromosome       Start         End Ref Alt  ...  \
# 0                   rs2126042      chr13  32329548.0  32329548.0   C   T  ...
# 1                 rs276174816      chr13  32333399.0  32333399.0   T   -  ...
# 2     rs587780560,rs864622682      chr13  32333398.0  32333399.0   -   T  ...
# 3                    rs543304      chr13  32338162.0  32338162.0   T   C  ...
# 4                    rs206075      chr13  32338918.0  32338918.0   A   G  ...
# ...                       ...        ...         ...         ...  ..  ..  ...
# 4715                               chr17  43104058.0  43104059.0          ...
# 4716                               chr17  43104058.0  43104058.0          ...
# 4717                               chr17  43104071.0  43104071.0          ...
# 4718                               chr17  43104070.0  43104071.0          ...
# 4719                rs8176128      chr17  43106433.0  43106433.0          ...
#
#      Variant_Classification     VAF  Genotype alt_count  ref_count       DP  \
# 0                    Intron   50.40       Het   16969.0      16702  33671.0
# 1                    Intron   22.38       Het    3308.0      11475  14783.0
# 2                    Intron    9.20       Het    1163.0      11475  12638.0
# 3                    Silent   48.41       Het   11897.0      12679  24576.0
# 4                    Silent  100.00    HomAlt    3289.0          0   3289.0
# ...                     ...     ...       ...       ...        ...      ...
# 4715                 Intron   26.35       Het     185.0        517    702.0
# 4716                 Intron   33.12       Het     256.0        517    773.0
# 4717                 Intron   31.17       Het     303.0        669    972.0
# 4718                 Intron   12.20       Het      93.0        669    762.0
# 4719                 Intron    7.73       Het      15.0        179    194.0
#
#       Clinical Relevance P/LP_Result Mode_of_Inheritance Disease_Name
# 0                 Benign    detected
# 1                           detected
# 2                           detected
# 3                 Benign    detected
# 4                 Benign    detected
# ...                  ...         ...                 ...          ...
# 4715                        detected
# 4716                        detected
# 4717                        detected
# 4718                        detected
# 4719              Benign    detected
#
# [4711 rows x 21 columns]

# %%
bahan_db_df.rename(columns={'Disease_Name': 'Disease Name'}, inplace=True)
all_columns = bahan_db_df.columns
desired_columns = ['Rundate','SampleID','Nucleotide [AAchange]', 'Clinical Relevance', 'Disease Name', 'Chromosome', 'dbSNP ID']
new_column_order = [col for col in desired_columns if col in all_columns] + [col for col in all_columns if col not in desired_columns]
new_column_order
bahan_db_df = bahan_db_df[new_column_order]
bahan_db_df
# Out:
#          Rundate     SampleID  \
# 0     28/08/2023  R2308161706
# 1     28/08/2023  R2308161706
# 2     28/08/2023  R2308161706
# 3     28/08/2023  R2308161706
# 4     28/08/2023  R2308161706
# ...          ...          ...
# 4715  16/06/2021  R2106290759
# 4716  16/06/2021  R2106290759
# 4717  16/06/2021  R2106290759
# 4718  16/06/2021  R2106290759
# 4719  16/06/2021  R2106290759
#
#                                   Nucleotide [AAchange] Clinical Relevance  \
# 0     NM_000059|g.chr13:32329548C>T|NM_000059|c.e8+5...             Benign
# 1     NM_000059|g.chr13:32333399delT|NM_000059|c.e10...
# 2     NM_000059|g.chr13:32333398_32333399insT|NM_000...
# 3     NM_000059|g.chr13:32338162T>C|NM_000059|c.3807T>C             Benign
# 4     NM_000059|g.chr13:32338918A>G|NM_000059|c.4563A>G             Benign
# ...                                                 ...                ...
# 4715  NM_007294|g.chr17:43104058_43104059delAA|c.e6-...
# 4716   NM_007294|g.chr17:43104058delA|c.e6-65TG>G|--|--
# 4717   NM_007294|g.chr17:43104071delA|c.e6-52TC>C|--|--
# 4718  NM_007294|g.chr17:43104070_43104071GA>AG|c.e6-...
# 4719     NM_007294|g.chr17:43106433A>T|c.e4-23T>A|--|--             Benign
#
#      Disease Name Chromosome                 dbSNP ID   Gene       Start  \
# 0                      chr13                rs2126042  BRCA2  32329548.0
# 1                      chr13              rs276174816  BRCA2  32333399.0
# 2                      chr13  rs587780560,rs864622682  BRCA2  32333398.0
# 3                      chr13                 rs543304  BRCA2  32338162.0
# 4                      chr13                 rs206075  BRCA2  32338918.0
# ...           ...        ...                      ...    ...         ...
# 4715                   chr17                           BRCA1  43104058.0
# 4716                   chr17                           BRCA1  43104058.0
# 4717                   chr17                           BRCA1  43104071.0
# 4718                   chr17                           BRCA1  43104070.0
# 4719                   chr17                rs8176128  BRCA1  43106433.0
#
#              End  ... Alt Variant Type Variant_Classification     VAF  \
# 0     32329548.0  ...   T          SNP                 Intron   50.40
# 1     32333399.0  ...   -          DEL                 Intron   22.38
# 2     32333399.0  ...   T          INS                 Intron    9.20
# 3     32338162.0  ...   C          SNP                 Silent   48.41
# 4     32338918.0  ...   G          SNP                 Silent  100.00
# ...          ...  ...  ..          ...                    ...     ...
# 4715  43104059.0  ...              DEL                 Intron   26.35
# 4716  43104058.0  ...              DEL                 Intron   33.12
# 4717  43104071.0  ...              DEL                 Intron   31.17
# 4718  43104071.0  ...              DNP                 Intron   12.20
# 4719  43106433.0  ...              SNP                 Intron    7.73
#
#       Genotype alt_count  ref_count       DP  P/LP_Result Mode_of_Inheritance
# 0          Het   16969.0      16702  33671.0     detected
# 1          Het    3308.0      11475  14783.0     detected
# 2          Het    1163.0      11475  12638.0     detected
# 3          Het   11897.0      12679  24576.0     detected
# 4       HomAlt    3289.0          0   3289.0     detected
# ...        ...       ...        ...      ...          ...                 ...
# 4715       Het     185.0        517    702.0     detected
# 4716       Het     256.0        517    773.0     detected
# 4717       Het     303.0        669    972.0     detected
# 4718       Het      93.0        669    762.0     detected
# 4719       Het      15.0        179    194.0     detected
#
# [4711 rows x 21 columns]

# %%
# Convert the 'Date' column to datetime format using the 'dayfirst' parameter
bahan_db_df['Rundate'] = pd.to_datetime(bahan_db_df['Rundate'], dayfirst=True, errors='coerce')

# Convert the datetime objects back to strings in the desired format
bahan_db_df['Rundate'] = bahan_db_df['Rundate'].dt.strftime('%Y/%m/%d')

bahan_db_df
# Out:
#          Rundate     SampleID  \
# 0     2023/08/28  R2308161706
# 1     2023/08/28  R2308161706
# 2     2023/08/28  R2308161706
# 3     2023/08/28  R2308161706
# 4     2023/08/28  R2308161706
# ...          ...          ...
# 4715  2021/06/16  R2106290759
# 4716  2021/06/16  R2106290759
# 4717  2021/06/16  R2106290759
# 4718  2021/06/16  R2106290759
# 4719  2021/06/16  R2106290759
#
#                                   Nucleotide [AAchange] Clinical Relevance  \
# 0     NM_000059|g.chr13:32329548C>T|NM_000059|c.e8+5...             Benign
# 1     NM_000059|g.chr13:32333399delT|NM_000059|c.e10...
# 2     NM_000059|g.chr13:32333398_32333399insT|NM_000...
# 3     NM_000059|g.chr13:32338162T>C|NM_000059|c.3807T>C             Benign
# 4     NM_000059|g.chr13:32338918A>G|NM_000059|c.4563A>G             Benign
# ...                                                 ...                ...
# 4715  NM_007294|g.chr17:43104058_43104059delAA|c.e6-...
# 4716   NM_007294|g.chr17:43104058delA|c.e6-65TG>G|--|--
# 4717   NM_007294|g.chr17:43104071delA|c.e6-52TC>C|--|--
# 4718  NM_007294|g.chr17:43104070_43104071GA>AG|c.e6-...
# 4719     NM_007294|g.chr17:43106433A>T|c.e4-23T>A|--|--             Benign
#
#      Disease Name Chromosome                 dbSNP ID   Gene       Start  \
# 0                      chr13                rs2126042  BRCA2  32329548.0
# 1                      chr13              rs276174816  BRCA2  32333399.0
# 2                      chr13  rs587780560,rs864622682  BRCA2  32333398.0
# 3                      chr13                 rs543304  BRCA2  32338162.0
# 4                      chr13                 rs206075  BRCA2  32338918.0
# ...           ...        ...                      ...    ...         ...
# 4715                   chr17                           BRCA1  43104058.0
# 4716                   chr17                           BRCA1  43104058.0
# 4717                   chr17                           BRCA1  43104071.0
# 4718                   chr17                           BRCA1  43104070.0
# 4719                   chr17                rs8176128  BRCA1  43106433.0
#
#              End  ... Alt Variant Type Variant_Classification     VAF  \
# 0     32329548.0  ...   T          SNP                 Intron   50.40
# 1     32333399.0  ...   -          DEL                 Intron   22.38
# 2     32333399.0  ...   T          INS                 Intron    9.20
# 3     32338162.0  ...   C          SNP                 Silent   48.41
# 4     32338918.0  ...   G          SNP                 Silent  100.00
# ...          ...  ...  ..          ...                    ...     ...
# 4715  43104059.0  ...              DEL                 Intron   26.35
# 4716  43104058.0  ...              DEL                 Intron   33.12
# 4717  43104071.0  ...              DEL                 Intron   31.17
# 4718  43104071.0  ...              DNP                 Intron   12.20
# 4719  43106433.0  ...              SNP                 Intron    7.73
#
#       Genotype alt_count  ref_count       DP  P/LP_Result Mode_of_Inheritance
# 0          Het   16969.0      16702  33671.0     detected
# 1          Het    3308.0      11475  14783.0     detected
# 2          Het    1163.0      11475  12638.0     detected
# 3          Het   11897.0      12679  24576.0     detected
# 4       HomAlt    3289.0          0   3289.0     detected
# ...        ...       ...        ...      ...          ...                 ...
# 4715       Het     185.0        517    702.0     detected
# 4716       Het     256.0        517    773.0     detected
# 4717       Het     303.0        669    972.0     detected
# 4718       Het      93.0        669    762.0     detected
# 4719       Het      15.0        179    194.0     detected
#
# [4711 rows x 21 columns]

# %%
bahan_db_df['Variant_Record'] = bahan_db_df.apply(lambda row: generate_unique_id(row['Rundate'] + ' | ' + row['SampleID'] + ' | ' + row['Nucleotide [AAchange]']), axis=1)
bahan_db_df
# Out:
#          Rundate     SampleID  \
# 0     2023/08/28  R2308161706
# 1     2023/08/28  R2308161706
# 2     2023/08/28  R2308161706
# 3     2023/08/28  R2308161706
# 4     2023/08/28  R2308161706
# ...          ...          ...
# 4715  2021/06/16  R2106290759
# 4716  2021/06/16  R2106290759
# 4717  2021/06/16  R2106290759
# 4718  2021/06/16  R2106290759
# 4719  2021/06/16  R2106290759
#
#                                   Nucleotide [AAchange] Clinical Relevance  \
# 0     NM_000059|g.chr13:32329548C>T|NM_000059|c.e8+5...             Benign
# 1     NM_000059|g.chr13:32333399delT|NM_000059|c.e10...
# 2     NM_000059|g.chr13:32333398_32333399insT|NM_000...
# 3     NM_000059|g.chr13:32338162T>C|NM_000059|c.3807T>C             Benign
# 4     NM_000059|g.chr13:32338918A>G|NM_000059|c.4563A>G             Benign
# ...                                                 ...                ...
# 4715  NM_007294|g.chr17:43104058_43104059delAA|c.e6-...
# 4716   NM_007294|g.chr17:43104058delA|c.e6-65TG>G|--|--
# 4717   NM_007294|g.chr17:43104071delA|c.e6-52TC>C|--|--
# 4718  NM_007294|g.chr17:43104070_43104071GA>AG|c.e6-...
# 4719     NM_007294|g.chr17:43106433A>T|c.e4-23T>A|--|--             Benign
#
#      Disease Name Chromosome                 dbSNP ID   Gene       Start  \
# 0                      chr13                rs2126042  BRCA2  32329548.0
# 1                      chr13              rs276174816  BRCA2  32333399.0
# 2                      chr13  rs587780560,rs864622682  BRCA2  32333398.0
# 3                      chr13                 rs543304  BRCA2  32338162.0
# 4                      chr13                 rs206075  BRCA2  32338918.0
# ...           ...        ...                      ...    ...         ...
# 4715                   chr17                           BRCA1  43104058.0
# 4716                   chr17                           BRCA1  43104058.0
# 4717                   chr17                           BRCA1  43104071.0
# 4718                   chr17                           BRCA1  43104070.0
# 4719                   chr17                rs8176128  BRCA1  43106433.0
#
#              End  ... Variant Type Variant_Classification     VAF Genotype  \
# 0     32329548.0  ...          SNP                 Intron   50.40      Het
# 1     32333399.0  ...          DEL                 Intron   22.38      Het
# 2     32333399.0  ...          INS                 Intron    9.20      Het
# 3     32338162.0  ...          SNP                 Silent   48.41      Het
# 4     32338918.0  ...          SNP                 Silent  100.00   HomAlt
# ...          ...  ...          ...                    ...     ...      ...
# 4715  43104059.0  ...          DEL                 Intron   26.35      Het
# 4716  43104058.0  ...          DEL                 Intron   33.12      Het
# 4717  43104071.0  ...          DEL                 Intron   31.17      Het
# 4718  43104071.0  ...          DNP                 Intron   12.20      Het
# 4719  43106433.0  ...          SNP                 Intron    7.73      Het
#
#       alt_count ref_count       DP P/LP_Result  Mode_of_Inheritance  \
# 0       16969.0     16702  33671.0    detected
# 1        3308.0     11475  14783.0    detected
# 2        1163.0     11475  12638.0    detected
# 3       11897.0     12679  24576.0    detected
# 4        3289.0         0   3289.0    detected
# ...         ...       ...      ...         ...                  ...
# 4715      185.0       517    702.0    detected
# 4716      256.0       517    773.0    detected
# 4717      303.0       669    972.0    detected
# 4718       93.0       669    762.0    detected
# 4719       15.0       179    194.0    detected
#
#                                          Variant_Record
# 0     5201543266722198448302727792882252135346055167...
# 1     4466717102594526795411669407002481201210545907...
# 2     7116067507930808411020796081540419444323770043...
# 3     3642310019828343596122381087503730772860215884...
# 4     8651653283064560796217934599777554921853306538...
# ...                                                 ...
# 4715  1102902324482417975543303342071834614822174312...
# 4716  4652138794628394476494338169852255308938157166...
# 4717  1099081651328035970588307099250787482781267803...
# 4718  2823897160382566124049125990911230891748716030...
# 4719  6604495542119739828720935633037059180053944184...
#
# [4711 rows x 22 columns]

# %%
bahan_db_df
# Out:
#          Rundate     SampleID  \
# 0     2023/08/28  R2308161706
# 1     2023/08/28  R2308161706
# 2     2023/08/28  R2308161706
# 3     2023/08/28  R2308161706
# 4     2023/08/28  R2308161706
# ...          ...          ...
# 4715  2021/06/16  R2106290759
# 4716  2021/06/16  R2106290759
# 4717  2021/06/16  R2106290759
# 4718  2021/06/16  R2106290759
# 4719  2021/06/16  R2106290759
#
#                                   Nucleotide [AAchange] Clinical Relevance  \
# 0     NM_000059|g.chr13:32329548C>T|NM_000059|c.e8+5...             Benign
# 1     NM_000059|g.chr13:32333399delT|NM_000059|c.e10...
# 2     NM_000059|g.chr13:32333398_32333399insT|NM_000...
# 3     NM_000059|g.chr13:32338162T>C|NM_000059|c.3807T>C             Benign
# 4     NM_000059|g.chr13:32338918A>G|NM_000059|c.4563A>G             Benign
# ...                                                 ...                ...
# 4715  NM_007294|g.chr17:43104058_43104059delAA|c.e6-...
# 4716   NM_007294|g.chr17:43104058delA|c.e6-65TG>G|--|--
# 4717   NM_007294|g.chr17:43104071delA|c.e6-52TC>C|--|--
# 4718  NM_007294|g.chr17:43104070_43104071GA>AG|c.e6-...
# 4719     NM_007294|g.chr17:43106433A>T|c.e4-23T>A|--|--             Benign
#
#      Disease Name Chromosome                 dbSNP ID   Gene       Start  \
# 0                      chr13                rs2126042  BRCA2  32329548.0
# 1                      chr13              rs276174816  BRCA2  32333399.0
# 2                      chr13  rs587780560,rs864622682  BRCA2  32333398.0
# 3                      chr13                 rs543304  BRCA2  32338162.0
# 4                      chr13                 rs206075  BRCA2  32338918.0
# ...           ...        ...                      ...    ...         ...
# 4715                   chr17                           BRCA1  43104058.0
# 4716                   chr17                           BRCA1  43104058.0
# 4717                   chr17                           BRCA1  43104071.0
# 4718                   chr17                           BRCA1  43104070.0
# 4719                   chr17                rs8176128  BRCA1  43106433.0
#
#              End  ... Variant Type Variant_Classification     VAF Genotype  \
# 0     32329548.0  ...          SNP                 Intron   50.40      Het
# 1     32333399.0  ...          DEL                 Intron   22.38      Het
# 2     32333399.0  ...          INS                 Intron    9.20      Het
# 3     32338162.0  ...          SNP                 Silent   48.41      Het
# 4     32338918.0  ...          SNP                 Silent  100.00   HomAlt
# ...          ...  ...          ...                    ...     ...      ...
# 4715  43104059.0  ...          DEL                 Intron   26.35      Het
# 4716  43104058.0  ...          DEL                 Intron   33.12      Het
# 4717  43104071.0  ...          DEL                 Intron   31.17      Het
# 4718  43104071.0  ...          DNP                 Intron   12.20      Het
# 4719  43106433.0  ...          SNP                 Intron    7.73      Het
#
#       alt_count ref_count       DP P/LP_Result  Mode_of_Inheritance  \
# 0       16969.0     16702  33671.0    detected
# 1        3308.0     11475  14783.0    detected
# 2        1163.0     11475  12638.0    detected
# 3       11897.0     12679  24576.0    detected
# 4        3289.0         0   3289.0    detected
# ...         ...       ...      ...         ...                  ...
# 4715      185.0       517    702.0    detected
# 4716      256.0       517    773.0    detected
# 4717      303.0       669    972.0    detected
# 4718       93.0       669    762.0    detected
# 4719       15.0       179    194.0    detected
#
#                                          Variant_Record
# 0     5201543266722198448302727792882252135346055167...
# 1     4466717102594526795411669407002481201210545907...
# 2     7116067507930808411020796081540419444323770043...
# 3     3642310019828343596122381087503730772860215884...
# 4     8651653283064560796217934599777554921853306538...
# ...                                                 ...
# 4715  1102902324482417975543303342071834614822174312...
# 4716  4652138794628394476494338169852255308938157166...
# 4717  1099081651328035970588307099250787482781267803...
# 4718  2823897160382566124049125990911230891748716030...
# 4719  6604495542119739828720935633037059180053944184...
#
# [4711 rows x 22 columns]

# %%
bahan_db_df.at[0,'Variant_Record']
duplicate_rows_specific = bahan_db_df[bahan_db_df.duplicated(['Variant_Record'])]
print(duplicate_rows_specific)
# Out:
# Empty DataFrame
# Columns: [Rundate, SampleID, Nucleotide [AAchange], Clinical Relevance, Disease Name, Chromosome, dbSNP ID, Gene, Start, End, Ref, Alt, Variant Type, Variant_Classification, VAF, Genotype, alt_count, ref_count, DP, P/LP_Result, Mode_of_Inheritance, Variant_Record]
# Index: []
#
# [0 rows x 22 columns]

# %%
final_column_name = {
    'Nucleotide [AAchange]':'Variant',
    'Clinical Relevance':'Clinical_Relevance',
    'Disease Name':'Disease_Name',
    'dbSNP ID':'dbSNP_ID',
    'Variant Type':'Variant_Type',
    'P/LP_Result':'P_LP_Result'
}
bahan_db_df.rename(columns=final_column_name, inplace=True)
bahan_db_df
# Out:
#          Rundate     SampleID  \
# 0     2023/08/28  R2308161706
# 1     2023/08/28  R2308161706
# 2     2023/08/28  R2308161706
# 3     2023/08/28  R2308161706
# 4     2023/08/28  R2308161706
# ...          ...          ...
# 4715  2021/06/16  R2106290759
# 4716  2021/06/16  R2106290759
# 4717  2021/06/16  R2106290759
# 4718  2021/06/16  R2106290759
# 4719  2021/06/16  R2106290759
#
#                                                 Variant Clinical_Relevance  \
# 0     NM_000059|g.chr13:32329548C>T|NM_000059|c.e8+5...             Benign
# 1     NM_000059|g.chr13:32333399delT|NM_000059|c.e10...
# 2     NM_000059|g.chr13:32333398_32333399insT|NM_000...
# 3     NM_000059|g.chr13:32338162T>C|NM_000059|c.3807T>C             Benign
# 4     NM_000059|g.chr13:32338918A>G|NM_000059|c.4563A>G             Benign
# ...                                                 ...                ...
# 4715  NM_007294|g.chr17:43104058_43104059delAA|c.e6-...
# 4716   NM_007294|g.chr17:43104058delA|c.e6-65TG>G|--|--
# 4717   NM_007294|g.chr17:43104071delA|c.e6-52TC>C|--|--
# 4718  NM_007294|g.chr17:43104070_43104071GA>AG|c.e6-...
# 4719     NM_007294|g.chr17:43106433A>T|c.e4-23T>A|--|--             Benign
#
#      Disease_Name Chromosome                 dbSNP_ID   Gene       Start  \
# 0                      chr13                rs2126042  BRCA2  32329548.0
# 1                      chr13              rs276174816  BRCA2  32333399.0
# 2                      chr13  rs587780560,rs864622682  BRCA2  32333398.0
# 3                      chr13                 rs543304  BRCA2  32338162.0
# 4                      chr13                 rs206075  BRCA2  32338918.0
# ...           ...        ...                      ...    ...         ...
# 4715                   chr17                           BRCA1  43104058.0
# 4716                   chr17                           BRCA1  43104058.0
# 4717                   chr17                           BRCA1  43104071.0
# 4718                   chr17                           BRCA1  43104070.0
# 4719                   chr17                rs8176128  BRCA1  43106433.0
#
#              End  ... Variant_Type Variant_Classification     VAF Genotype  \
# 0     32329548.0  ...          SNP                 Intron   50.40      Het
# 1     32333399.0  ...          DEL                 Intron   22.38      Het
# 2     32333399.0  ...          INS                 Intron    9.20      Het
# 3     32338162.0  ...          SNP                 Silent   48.41      Het
# 4     32338918.0  ...          SNP                 Silent  100.00   HomAlt
# ...          ...  ...          ...                    ...     ...      ...
# 4715  43104059.0  ...          DEL                 Intron   26.35      Het
# 4716  43104058.0  ...          DEL                 Intron   33.12      Het
# 4717  43104071.0  ...          DEL                 Intron   31.17      Het
# 4718  43104071.0  ...          DNP                 Intron   12.20      Het
# 4719  43106433.0  ...          SNP                 Intron    7.73      Het
#
#       alt_count ref_count       DP P_LP_Result  Mode_of_Inheritance  \
# 0       16969.0     16702  33671.0    detected
# 1        3308.0     11475  14783.0    detected
# 2        1163.0     11475  12638.0    detected
# 3       11897.0     12679  24576.0    detected
# 4        3289.0         0   3289.0    detected
# ...         ...       ...      ...         ...                  ...
# 4715      185.0       517    702.0    detected
# 4716      256.0       517    773.0    detected
# 4717      303.0       669    972.0    detected
# 4718       93.0       669    762.0    detected
# 4719       15.0       179    194.0    detected
#
#                                          Variant_Record
# 0     5201543266722198448302727792882252135346055167...
# 1     4466717102594526795411669407002481201210545907...
# 2     7116067507930808411020796081540419444323770043...
# 3     3642310019828343596122381087503730772860215884...
# 4     8651653283064560796217934599777554921853306538...
# ...                                                 ...
# 4715  1102902324482417975543303342071834614822174312...
# 4716  4652138794628394476494338169852255308938157166...
# 4717  1099081651328035970588307099250787482781267803...
# 4718  2823897160382566124049125990911230891748716030...
# 4719  6604495542119739828720935633037059180053944184...
#
# [4711 rows x 22 columns]

# %%
table_name1 = 'db_var'
table_name2 = 'db_var_version_history'

# SQL statement for creating a table
create_table_sql1 = f"""
CREATE TABLE IF NOT EXISTS {table_name1} (
    `Rundate` TEXT,
    `SampleID` TEXT,
    `Variant` TEXT,
    `Clinical_Relevance` TEXT,
    `Disease_Name` TEXT,
    `Chromosome` TEXT,
    `dbSNP_ID` TEXT,
    `Gene` TEXT,
    `Start` TEXT,
    `End` TEXT,
    `Ref` TEXT,
    `Alt` TEXT,
    `Variant_Type` TEXT,
    `Variant_Classification` TEXT,
    `VAF` TEXT,
    `Genotype` TEXT,
    `alt_count` TEXT,
    `ref_count` TEXT,
    `DP` TEXT,
    `P_LP_Result` TEXT,
    `Mode_of_Inheritance` TEXT,
    `Variant_Record` TEXT PRIMARY KEY
);
"""


# SQL statement for creating a table
create_table_sql2 = f"""
CREATE TABLE IF NOT EXISTS {table_name2} (
    `Version_ID` INTEGER PRIMARY KEY AUTOINCREMENT,
    `Variant_Record` TEXT,
    `Rundate` TEXT,
    `Changed_Column` TEXT,
    `Previous_Value` TEXT,
    `New_Value` TEXT,
    `Changed_By` TEXT,
    `Change_Date` TIMESTAMP DEFAULT CURRENT_TIMESTAMP,
    FOREIGN KEY(`Variant_Record`) REFERENCES {table_name1} (`Variant_Record`)
);
"""

# %%
import pandas as pd
import sqlite3


vava_db_dir = '.'
database_file = 'BRCAs_testing.db'


# Remove duplicates based on the 'Variant Record' column, keeping the first occurrence
df_unique = bahan_db_df.drop_duplicates(subset=['Variant_Record'], keep='first')    


# Replace 'your_database.sqlite' with the path to your SQLite file
db_path = f'{vava_db_dir}/{database_file}'

# Connect to the SQLite database
conn = sqlite3.connect(db_path)
cursor = conn.cursor()



# Execute the SQL statement to create the table
cursor.execute(create_table_sql1)
cursor.execute(create_table_sql2)

# Insert the deduplicated data into the SQL table
df_unique.to_sql(table_name1, conn, if_exists='append', index=False, method='multi', chunksize=500)

# Verify insertion by querying the first 5 rows
cursor.execute(f"SELECT * FROM {table_name1} LIMIT 5;")
rows = cursor.fetchall()

# Display the first 5 rows from the database for verification
for row in rows:
    print(row)

# Verify insertion by querying the first 5 rows
cursor.execute(f"SELECT * FROM {table_name2} LIMIT 5;")
rows = cursor.fetchall()

# Display the first 5 rows from the database for verification
for row in rows:
    print(row)


# Close the connection to the database
conn.close()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# Cell In[15], line 23
#      18 cursor = conn.cursor()
#      22 # Execute the SQL statement to create the table
# ---> 23 cursor.execute(create_table_sql1)
#      24 cursor.execute(create_table_sql2)
#      26 # Insert the deduplicated data into the SQL table
#
# OperationalError: database is locked

# %%
'''
import pandas as pd
import sqlite3


vava_db_dir = '/home/sysadmin/vava_db/'
database_file = 'TSHCvar_empty.db'


# Remove duplicates based on the 'Variant Record' column, keeping the first occurrence
df_unique = bahan_db_df.drop_duplicates(subset=['Variant_Record'], keep='first')
dummy_df = df_unique.head(1)
dummy_df

table_name1 = 'db_var'
table_name2 = 'db_var_version_history'

# Replace 'your_database.sqlite' with the path to your SQLite file
db_path = f'{vava_db_dir}/{database_file}'

# Connect to the SQLite database
conn = sqlite3.connect(db_path)
cursor = conn.cursor()


# Execute the SQL statement to create the table
cursor.execute(create_table_sql1)
cursor.execute(create_table_sql2)

# Insert the deduplicated data into the SQL table
dummy_df.to_sql(table_name1, conn, if_exists='append', index=False, method='multi', chunksize=500)

# Verify insertion by querying the first 5 rows
cursor.execute(f"SELECT * FROM {table_name1} LIMIT 5;")
rows = cursor.fetchall()

# Display the first 5 rows from the database for verification
for row in rows:
    print(row)

# Verify insertion by querying the first 5 rows
cursor.execute(f"SELECT * FROM {table_name2} LIMIT 5;")
rows = cursor.fetchall()

# Display the first 5 rows from the database for verification
for row in rows:
    print(row)


# Close the connection to the database
conn.close()
'''

# %%
'''
save_to_excel('/mnt/mol/test_db.xlsx', dfs={'Sheet1':bahan_db_df})
'''

# %%
'''
`Rundate`, `SampleID`, `Nucleotide [AAchange]`, `Clinical Relevance`, `Disease Name`, `Chromosome`, `dbSNP ID`, `Gene`, `Start`, `End`, `Ref`, `Alt`, `Variant Type`, `Variant_Classification`, `VAF`, `Genotype`, `alt_count`, `ref_count`, `DP`, `P/LP_Result`, `Mode_of_Inheritance`, `Variant_Record`, `changed_by`
'''
