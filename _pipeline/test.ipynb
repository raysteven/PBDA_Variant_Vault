# %%
from sqlalchemy import create_engine
import pandas as pd

# Create a simple DataFrame
df = pd.DataFrame({'column1': [1, 2], 'column2': [3, 4]})

# Create SQLAlchemy engine
engine = create_engine('sqlite:////home/sysadmin/database.sqlite')

# Write DataFrame to SQL
df.to_sql('test_table', engine, index=False, if_exists='replace')

print("Operation completed successfully.")
# Out:
# Operation completed successfully.

# %%
import sqlite3
con = sqlite3.connect("tutorial.sql")
cur = con.cursor()

# %%
cur.execute("CREATE TABLE movie(title, year, score)")
res = cur.execute("SELECT name FROM sqlite_master")
res.fetchone()('movie',)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# <ipython-input-96-15960b5ec071> in <module>
# ----> 1 cur.execute("CREATE TABLE movie(title, year, score)")
#       2 res = cur.execute("SELECT name FROM sqlite_master")
#       3 res.fetchone()('movie',)
#
# OperationalError: database is locked

# %%
import pandas as pd

# Create a DataFrame
data = {
    'BookID': [1, 2, 3],
    'Title': ['To Kill a Mockingbird', '1984', 'The Great Gatsby'],
    'Author': ['Harper Lee', 'George Orwell', 'F. Scott Fitzgerald'],
    'Year': [1960, 1949, 1925]
}
df = pd.DataFrame(data)

# Save the DataFrame to an Excel file
excel_file = 'books.xlsx'
df.to_excel(excel_file, index=False)

# %%
# !pip install pandas openpyxl sqlalchemy pymysql
# Out:
# ...
#      |████████████████████████████████| 44 kB 1.7 MB/s eta 0:00:011
# ...

# %%
from sqlalchemy import create_engine

# Read the Excel file
df = pd.read_excel(excel_file)

# Database connection string
# NOTE: Replace the placeholders with your actual database credentials
engine = create_engine('mysql+pymysql://sysadmin:P@ssw0rd@psj-brca-svr-02:3306/database_name')

# Insert the data into the MySQL database table named 'books'
# If the table doesn't exist, it will be created automatically
df.to_sql('books', con=engine, if_exists='replace', index=False)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# ~/anaconda3/lib/python3.8/site-packages/sqlalchemy/engine/base.py in _wrap_pool_connect(self, fn, connection)
#    3140         try:
# -> 3141             return fn()
#    3142         except dialect.dbapi.Error as e:
#
# ~/anaconda3/lib/python3.8/site-packages/sqlalchemy/pool/base.py in connect(self)
#     300         """
# --> 301         return _ConnectionFairy._checkout(self)
#     302
#
# ~/anaconda3/lib/python3.8/site-packages/sqlalchemy/pool/base.py in _checkout(cls, pool, threadconns, fairy)
#     754         if not fairy:
# --> 755             fairy = _ConnectionRecord.checkout(pool)
#     756
#
# ~/anaconda3/lib/python3.8/site-packages/sqlalchemy/pool/base.py in checkout(cls, pool)
#     418     def checkout(cls, pool):
# --> 419         rec = pool._do_get()
#     420         try:
#
# ...
